# %%
pip install steamspypi
# Out:
# Requirement already satisfied: steamspypi in c:\users\lenovo\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from steamspypi) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->steamspypi) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->steamspypi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->steamspypi) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->steamspypi) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import steamspypi

data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '0'

data = steamspypi.download(data_request)
data
# Out:
# {'570': {'appid': 570,
#   'name': 'Dota 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1343537,
#   'negative': 260064,
#   'userscore': 0,
#   'owners': '100,000,000 .. 200,000,000',
#   'average_forever': 33549,
#   'average_2weeks': 1553,
#   'median_forever': 1037,
#   'median_2weeks': 795,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 569616},
#  '730': {'appid': 730,
#   'name': 'Counter-Strike: Global Offensive',
#   'developer': 'Valve, Hidden Path Entertainment',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 5296582,
#   'negative': 713258,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 27948,
#   'average_2weeks': 896,
#   'median_forever': 5974,
#   'median_2weeks': 340,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 695153},
#  '578080': {'appid': 578080,
#   'name': 'PUBG: BATTLEGROUNDS',
#   'developer': 'KRAFTON, Inc.',
#   'publisher': 'KRAFTON, Inc.',
#   'score_rank': '',
#   'positive': 1020533,
#   'negative': 834227,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 24119,
#   'average_2weeks': 455,
#   'median_forever': 10045,
#   'median_2weeks': 166,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 286942},
#  '440': {'appid': 440,
#   'name': 'Team Fortress 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 771213,
#   'negative': 51672,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 9077,
#   'average_2weeks': 2505,
#   'median_forever': 365,
#   'median_2weeks': 237,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 103460},
#  '304930': {'appid': 304930,
#   'name': 'Unturned',
#   'developer': 'Smartly Dressed Games',
#   'publisher': 'Smartly Dressed Games',
#   'score_rank': '',
#   'positive': 416405,
#   'negative': 39089,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5096,
#   'average_2weeks': 1875,
#   'median_forever': 339,
#   'median_2weeks': 413,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 29490},
#  '230410': {'appid': 230410,
#   'name': 'Warframe',
#   'developer': 'Digital Extremes',
#   'publisher': 'Digital Extremes',
#   'score_rank': '',
#   'positive': 413961,
#   'negative': 43642,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 9511,
#   'average_2weeks': 1415,
#   'median_forever': 403,
#   'median_2weeks': 628,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 52688},
#  '271590': {'appid': 271590,
#   'name': 'Grand Theft Auto V',
#   'developer': 'Rockstar North',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 1035169,
#   'negative': 200049,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 12857,
#   'average_2weeks': 447,
#   'median_forever': 6209,
#   'median_2weeks': 101,
#   'price': '2998',
#   'initialprice': '2998',
#   'discount': '0',
#   'ccu': 89418},
#  '550': {'appid': 550,
#   'name': 'Left 4 Dead 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 541252,
#   'negative': 14737,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 2089,
#   'average_2weeks': 139,
#   'median_forever': 580,
#   'median_2weeks': 55,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 15718},
#  '252490': {'appid': 252490,
#   'name': 'Rust',
#   'developer': 'Facepunch Studios',
#   'publisher': 'Facepunch Studios',
#   'score_rank': '',
#   'positive': 605718,
#   'negative': 92525,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 19351,
#   'average_2weeks': 1028,
#   'median_forever': 3117,
#   'median_2weeks': 640,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 73507},
#  '291550': {'appid': 291550,
#   'name': 'Brawlhalla',
#   'developer': 'Blue Mammoth Games',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 213331,
#   'negative': 39162,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1270,
#   'average_2weeks': 271,
#   'median_forever': 185,
#   'median_2weeks': 63,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 18878},
#  '1063730': {'appid': 1063730,
#   'name': 'New World',
#   'developer': 'Amazon Games',
#   'publisher': 'Amazon Games',
#   'score_rank': '',
#   'positive': 127666,
#   'negative': 45268,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5421,
#   'average_2weeks': 1717,
#   'median_forever': 3404,
#   'median_2weeks': 802,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 159838},
#  '4000': {'appid': 4000,
#   'name': "Garry's Mod",
#   'developer': 'Facepunch Studios',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 732278,
#   'negative': 25866,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 8706,
#   'average_2weeks': 602,
#   'median_forever': 1265,
#   'median_2weeks': 114,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 26876},
#  '359550': {'appid': 359550,
#   'name': "Tom Clancy's Rainbow Six Siege",
#   'developer': 'Ubisoft Montreal',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 867852,
#   'negative': 125001,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 14230,
#   'average_2weeks': 450,
#   'median_forever': 3265,
#   'median_2weeks': 161,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 44619},
#  '1172470': {'appid': 1172470,
#   'name': 'Apex Legends',
#   'developer': 'Respawn Entertainment',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 295221,
#   'negative': 46310,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 4870,
#   'average_2weeks': 862,
#   'median_forever': 713,
#   'median_2weeks': 451,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 199528},
#  '945360': {'appid': 945360,
#   'name': 'Among Us',
#   'developer': 'Innersloth',
#   'publisher': 'Innersloth',
#   'score_rank': '',
#   'positive': 543747,
#   'negative': 44084,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1310,
#   'average_2weeks': 114,
#   'median_forever': 690,
#   'median_2weeks': 66,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 13065},
#  '236390': {'appid': 236390,
#   'name': 'War Thunder',
#   'developer': 'Gaijin Entertainment',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 204398,
#   'negative': 54002,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5576,
#   'average_2weeks': 1206,
#   'median_forever': 438,
#   'median_2weeks': 638,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31163},
#  '340': {'appid': 340,
#   'name': 'Half-Life 2: Lost Coast',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 8511,
#   'negative': 1217,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 221,
#   'average_2weeks': 0,
#   'median_forever': 22,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 15},
#  '218620': {'appid': 218620,
#   'name': 'PAYDAY 2',
#   'developer': 'OVERKILL - a Starbreeze Studio.',
#   'publisher': 'Starbreeze Publishing AB',
#   'score_rank': '',
#   'positive': 484415,
#   'negative': 61402,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 4810,
#   'average_2weeks': 1599,
#   'median_forever': 611,
#   'median_2weeks': 147,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 25958},
#  '238960': {'appid': 238960,
#   'name': 'Path of Exile',
#   'developer': 'Grinding Gear Games',
#   'publisher': 'Grinding Gear Games',
#   'score_rank': '',
#   'positive': 157410,
#   'negative': 15981,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5977,
#   'average_2weeks': 1920,
#   'median_forever': 464,
#   'median_2weeks': 2275,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 46035},
#  '1085660': {'appid': 1085660,
#   'name': 'Destiny 2',
#   'developer': 'Bungie',
#   'publisher': 'Bungie',
#   'score_rank': '',
#   'positive': 354430,
#   'negative': 64735,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8018,
#   'average_2weeks': 1028,
#   'median_forever': 397,
#   'median_2weeks': 827,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 44827},
#  '10': {'appid': 10,
#   'name': 'Counter-Strike',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 184098,
#   'negative': 4788,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 10209,
#   'average_2weeks': 733,
#   'median_forever': 217,
#   'median_2weeks': 124,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 14562},
#  '892970': {'appid': 892970,
#   'name': 'Valheim',
#   'developer': 'Iron Gate AB',
#   'publisher': ' Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 266535,
#   'negative': 12637,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2433,
#   'average_2weeks': 584,
#   'median_forever': 1417,
#   'median_2weeks': 525,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 17996},
#  '444090': {'appid': 444090,
#   'name': 'Paladins',
#   'developer': 'Evil Mojo Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 269165,
#   'negative': 44391,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2841,
#   'average_2weeks': 561,
#   'median_forever': 488,
#   'median_2weeks': 426,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9221},
#  '272060': {'appid': 272060,
#   'name': 'Serena',
#   'developer': 'Senscape',
#   'publisher': 'Senscape',
#   'score_rank': '',
#   'positive': 4844,
#   'negative': 1425,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 817,
#   'average_2weeks': 0,
#   'median_forever': 5,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4},
#  '431960': {'appid': 431960,
#   'name': 'Wallpaper Engine',
#   'developer': 'Wallpaper Engine Team',
#   'publisher': 'Wallpaper Engine Team',
#   'score_rank': '',
#   'positive': 419756,
#   'negative': 8887,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2794,
#   'average_2weeks': 198,
#   'median_forever': 669,
#   'median_2weeks': 11,
#   'price': '399',
#   'initialprice': '399',
#   'discount': '0',
#   'ccu': 60865},
#  '49520': {'appid': 49520,
#   'name': 'Borderlands 2',
#   'developer': 'Gearbox Software, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 237581,
#   'negative': 16170,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3430,
#   'average_2weeks': 386,
#   'median_forever': 1007,
#   'median_2weeks': 557,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 3563},
#  '1097150': {'appid': 1097150,
#   'name': 'Fall Guys: Ultimate Knockout',
#   'developer': 'Mediatonic',
#   'publisher': '',
#   'score_rank': '',
#   'positive': 330623,
#   'negative': 66978,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 956,
#   'average_2weeks': 73,
#   'median_forever': 465,
#   'median_2weeks': 31,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 5240},
#  '1091500': {'appid': 1091500,
#   'name': 'Cyberpunk 2077',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 333656,
#   'negative': 109053,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3240,
#   'average_2weeks': 313,
#   'median_forever': 2380,
#   'median_2weeks': 183,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 8893},
#  '227940': {'appid': 227940,
#   'name': 'Heroes & Generals',
#   'developer': 'RETO MOTO',
#   'publisher': 'RETO MOTO',
#   'score_rank': '',
#   'positive': 91549,
#   'negative': 43619,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 974,
#   'average_2weeks': 276,
#   'median_forever': 87,
#   'median_2weeks': 330,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2214},
#  '292030': {'appid': 292030,
#   'name': 'The Witcher 3: Wild Hunt',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 550555,
#   'negative': 11651,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3040,
#   'average_2weeks': 349,
#   'median_forever': 889,
#   'median_2weeks': 103,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 16602},
#  '381210': {'appid': 381210,
#   'name': 'Dead by Daylight',
#   'developer': 'Behaviour Interactive Inc.',
#   'publisher': 'Behaviour Interactive Inc.',
#   'score_rank': '',
#   'positive': 445436,
#   'negative': 98688,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 7944,
#   'average_2weeks': 663,
#   'median_forever': 1178,
#   'median_2weeks': 352,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 47088},
#  '105600': {'appid': 105600,
#   'name': 'Terraria',
#   'developer': 'Re-Logic',
#   'publisher': 'Re-Logic',
#   'score_rank': '',
#   'positive': 816680,
#   'negative': 17412,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8001,
#   'average_2weeks': 436,
#   'median_forever': 2581,
#   'median_2weeks': 142,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 28709},
#  '291480': {'appid': 291480,
#   'name': 'Warface',
#   'developer': 'MY.GAMES',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 49547,
#   'negative': 23104,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 615,
#   'average_2weeks': 94,
#   'median_forever': 111,
#   'median_2weeks': 148,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2621},
#  '1468810': {'appid': 1468810,
#   'name': '鬼谷八荒 Tale of Immortal',
#   'developer': '鬼谷工作室',
#   'publisher': '鬼谷工作室, Lightning Games',
#   'score_rank': '',
#   'positive': 102648,
#   'negative': 15717,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3048,
#   'average_2weeks': 1583,
#   'median_forever': 1907,
#   'median_2weeks': 857,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 18346},
#  '552990': {'appid': 552990,
#   'name': 'World of Warships',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 72446,
#   'negative': 18099,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1775,
#   'average_2weeks': 421,
#   'median_forever': 181,
#   'median_2weeks': 788,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9887},
#  '301520': {'appid': 301520,
#   'name': 'Robocraft',
#   'developer': 'Freejam',
#   'publisher': 'Freejam',
#   'score_rank': '',
#   'positive': 85926,
#   'negative': 32316,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1299,
#   'average_2weeks': 239,
#   'median_forever': 184,
#   'median_2weeks': 273,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 291},
#  '620': {'appid': 620,
#   'name': 'Portal 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 265305,
#   'negative': 3236,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 900,
#   'average_2weeks': 137,
#   'median_forever': 479,
#   'median_2weeks': 196,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 1532},
#  '227300': {'appid': 227300,
#   'name': 'Euro Truck Simulator 2',
#   'developer': 'SCS Software',
#   'publisher': 'SCS Software',
#   'score_rank': '',
#   'positive': 470322,
#   'negative': 11536,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5461,
#   'average_2weeks': 391,
#   'median_forever': 1587,
#   'median_2weeks': 190,
#   'price': '499',
#   'initialprice': '1999',
#   'discount': '75',
#   'ccu': 36135},
#  '550650': {'appid': 550650,
#   'name': 'Black Squad',
#   'developer': 'VALOFE, NS STUDIO',
#   'publisher': 'VALOFE',
#   'score_rank': '',
#   'positive': 59207,
#   'negative': 17991,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1099,
#   'average_2weeks': 21,
#   'median_forever': 81,
#   'median_2weeks': 26,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1266},
#  '320': {'appid': 320,
#   'name': 'Half-Life 2: Deathmatch',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 9020,
#   'negative': 1005,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1043,
#   'average_2weeks': 0,
#   'median_forever': 39,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 234},
#  '240': {'appid': 240,
#   'name': 'Counter-Strike: Source',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 124196,
#   'negative': 5011,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 6125,
#   'average_2weeks': 190,
#   'median_forever': 435,
#   'median_2weeks': 270,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 5080},
#  '755790': {'appid': 755790,
#   'name': 'Ring of Elysium',
#   'developer': 'Aurora Studio',
#   'publisher': 'TCH Scarlet Limited',
#   'score_rank': '',
#   'positive': 73617,
#   'negative': 25217,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 662,
#   'average_2weeks': 21,
#   'median_forever': 109,
#   'median_2weeks': 28,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1380},
#  '252950': {'appid': 252950,
#   'name': 'Rocket League',
#   'developer': 'Psyonix LLC',
#   'publisher': 'Psyonix LLC',
#   'score_rank': '',
#   'positive': 479646,
#   'negative': 59784,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 14707,
#   'average_2weeks': 624,
#   'median_forever': 2553,
#   'median_2weeks': 384,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 32799},
#  '386360': {'appid': 386360,
#   'name': 'SMITE',
#   'developer': 'Titan Forge Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 74093,
#   'negative': 17977,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 4670,
#   'average_2weeks': 375,
#   'median_forever': 199,
#   'median_2weeks': 284,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 17090},
#  '477160': {'appid': 477160,
#   'name': 'Human: Fall Flat',
#   'developer': 'No Brakes Games',
#   'publisher': 'Curve Games',
#   'score_rank': '',
#   'positive': 142048,
#   'negative': 8211,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 746,
#   'average_2weeks': 225,
#   'median_forever': 350,
#   'median_2weeks': 64,
#   'price': '679',
#   'initialprice': '1999',
#   'discount': '66',
#   'ccu': 6853},
#  '322330': {'appid': 322330,
#   'name': "Don't Starve Together",
#   'developer': 'Klei Entertainment',
#   'publisher': 'Klei Entertainment',
#   'score_rank': '',
#   'positive': 280268,
#   'negative': 11175,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2335,
#   'average_2weeks': 341,
#   'median_forever': 483,
#   'median_2weeks': 120,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 20773},
#  '433850': {'appid': 433850,
#   'name': 'Z1 Battle Royale',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 115763,
#   'negative': 93225,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2273,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 101},
#  '413150': {'appid': 413150,
#   'name': 'Stardew Valley',
#   'developer': 'ConcernedApe',
#   'publisher': 'ConcernedApe',
#   'score_rank': '',
#   'positive': 396755,
#   'negative': 8153,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3224,
#   'average_2weeks': 293,
#   'median_forever': 1562,
#   'median_2weeks': 189,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 25123},
#  '275390': {'appid': 275390,
#   'name': 'Guacamelee! Super Turbo Championship Edition',
#   'developer': 'DrinkBox Studios',
#   'publisher': 'DrinkBox Studios',
#   'score_rank': '',
#   'positive': 5238,
#   'negative': 420,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 146,
#   'average_2weeks': 0,
#   'median_forever': 66,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 18},
#  '739630': {'appid': 739630,
#   'name': 'Phasmophobia',
#   'developer': 'Kinetic Games',
#   'publisher': 'Kinetic Games',
#   'score_rank': '',
#   'positive': 342985,
#   'negative': 10064,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1315,
#   'average_2weeks': 133,
#   'median_forever': 741,
#   'median_2weeks': 92,
#   'price': '1399',
#   'initialprice': '1399',
#   'discount': '0',
#   'ccu': 15264},
#  '220': {'appid': 220,
#   'name': 'Half-Life 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 128402,
#   'negative': 3480,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 806,
#   'average_2weeks': 229,
#   'median_forever': 409,
#   'median_2weeks': 229,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 680},
#  '346110': {'appid': 346110,
#   'name': 'ARK: Survival Evolved',
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'publisher': 'Studio Wildcard',
#   'score_rank': '',
#   'positive': 383425,
#   'negative': 90947,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 11724,
#   'average_2weeks': 1494,
#   'median_forever': 1663,
#   'median_2weeks': 1028,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 42817},
#  '130': {'appid': 130,
#   'name': 'Half-Life: Blue Shift',
#   'developer': 'Gearbox Software',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 8898,
#   'negative': 867,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 819,
#   'average_2weeks': 0,
#   'median_forever': 92,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 29},
#  '417910': {'appid': 417910,
#   'name': 'Street Warriors Online',
#   'developer': 'Crazy Rocks Studios',
#   'publisher': 'Crazy Rocks Studios',
#   'score_rank': '',
#   'positive': 973,
#   'negative': 710,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 61,
#   'average_2weeks': 0,
#   'median_forever': 52,
#   'median_2weeks': 0,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 0},
#  '242760': {'appid': 242760,
#   'name': 'The Forest',
#   'developer': 'Endnight Games Ltd',
#   'publisher': 'Endnight Games Ltd',
#   'score_rank': '',
#   'positive': 298737,
#   'negative': 15961,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1747,
#   'average_2weeks': 164,
#   'median_forever': 859,
#   'median_2weeks': 153,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 6514},
#  '582010': {'appid': 582010,
#   'name': 'Monster Hunter: World',
#   'developer': 'CAPCOM Co., Ltd.',
#   'publisher': 'CAPCOM Co., Ltd.',
#   'score_rank': '',
#   'positive': 284082,
#   'negative': 51548,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8749,
#   'average_2weeks': 636,
#   'median_forever': 2223,
#   'median_2weeks': 492,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 18603},
#  '400': {'appid': 400,
#   'name': 'Portal',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 94820,
#   'negative': 1545,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 398,
#   'average_2weeks': 14,
#   'median_forever': 167,
#   'median_2weeks': 19,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 323},
#  '8930': {'appid': 8930,
#   'name': "Sid Meier's Civilization V",
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 172823,
#   'negative': 6897,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 7463,
#   'average_2weeks': 629,
#   'median_forever': 2830,
#   'median_2weeks': 567,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 17425},
#  '532210': {'appid': 532210,
#   'name': 'Life is Strange 2',
#   'developer': 'DONTNOD Entertainment, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 21094,
#   'negative': 3885,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 412,
#   'average_2weeks': 0,
#   'median_forever': 209,
#   'median_2weeks': 0,
#   'price': '3196',
#   'initialprice': '3196',
#   'discount': '0',
#   'ccu': 161},
#  '218230': {'appid': 218230,
#   'name': 'PlanetSide 2',
#   'developer': 'Rogue Planet Games',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 52096,
#   'negative': 11413,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1665,
#   'average_2weeks': 572,
#   'median_forever': 157,
#   'median_2weeks': 848,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1520},
#  '72850': {'appid': 72850,
#   'name': 'The Elder Scrolls V: Skyrim',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 288909,
#   'negative': 15745,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 7073,
#   'average_2weeks': 177,
#   'median_forever': 3213,
#   'median_2weeks': 262,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 6171},
#  '70': {'appid': 70,
#   'name': 'Half-Life',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 64692,
#   'negative': 2339,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1888,
#   'average_2weeks': 25,
#   'median_forever': 154,
#   'median_2weeks': 25,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 491},
#  '444200': {'appid': 444200,
#   'name': 'World of Tanks Blitz',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 74412,
#   'negative': 18438,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2659,
#   'average_2weeks': 1174,
#   'median_forever': 151,
#   'median_2weeks': 1640,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31091},
#  '80': {'appid': 80,
#   'name': 'Counter-Strike: Condition Zero',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 18055,
#   'negative': 1766,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 857,
#   'average_2weeks': 0,
#   'median_forever': 44,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 440},
#  '261550': {'appid': 261550,
#   'name': 'Mount & Blade II: Bannerlord',
#   'developer': 'TaleWorlds Entertainment',
#   'publisher': 'TaleWorlds Entertainment',
#   'score_rank': '',
#   'positive': 150188,
#   'negative': 22240,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5220,
#   'average_2weeks': 656,
#   'median_forever': 3571,
#   'median_2weeks': 720,
#   'price': '4999',
#   'initialprice': '4999',
#   'discount': '0',
#   'ccu': 14339},
#  '251570': {'appid': 251570,
#   'name': '7 Days to Die',
#   'developer': 'The Fun Pimps',
#   'publisher': 'The Fun Pimps Entertainment LLC',
#   'score_rank': '',
#   'positive': 164552,
#   'negative': 23410,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5037,
#   'average_2weeks': 747,
#   'median_forever': 1310,
#   'median_2weeks': 416,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 17585},
#  '96000': {'appid': 96000,
#   'name': 'The Tiny Bang Story',
#   'developer': 'Colibri Games',
#   'publisher': 'Colibri Games',
#   'score_rank': '',
#   'positive': 5075,
#   'negative': 723,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 326,
#   'average_2weeks': 0,
#   'median_forever': 315,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 192},
#  '1089350': {'appid': 1089350,
#   'name': 'NBA 2K20',
#   'developer': 'Visual Concepts',
#   'publisher': '2K',
#   'score_rank': '',
#   'positive': 30270,
#   'negative': 29147,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 9188,
#   'average_2weeks': 381,
#   'median_forever': 2367,
#   'median_2weeks': 395,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 4666},
#  '224260': {'appid': 224260,
#   'name': 'No More Room in Hell',
#   'developer': 'No More Room in Hell Team',
#   'publisher': 'Lever Games',
#   'score_rank': '',
#   'positive': 56746,
#   'negative': 6533,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 501,
#   'average_2weeks': 30,
#   'median_forever': 107,
#   'median_2weeks': 49,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 881},
#  '370910': {'appid': 370910,
#   'name': 'Kathy Rain',
#   'developer': 'Clifftop Games',
#   'publisher': 'Raw Fury',
#   'score_rank': '',
#   'positive': 3135,
#   'negative': 255,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1636,
#   'average_2weeks': 246,
#   'median_forever': 270,
#   'median_2weeks': 246,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 5},
#  '219990': {'appid': 219990,
#   'name': 'Grim Dawn',
#   'developer': 'Crate Entertainment',
#   'publisher': 'Crate Entertainment',
#   'score_rank': '',
#   'positive': 65139,
#   'negative': 4624,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2414,
#   'average_2weeks': 164,
#   'median_forever': 1089,
#   'median_2weeks': 164,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 4880},
#  '1046930': {'appid': 1046930,
#   'name': 'Dota Underlords',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 72698,
#   'negative': 15168,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1742,
#   'average_2weeks': 596,
#   'median_forever': 272,
#   'median_2weeks': 1131,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3107},
#  '333930': {'appid': 333930,
#   'name': 'Dirty Bomb',
#   'developer': 'Splash Damage',
#   'publisher': 'Warchest Ltd.',
#   'score_rank': '',
#   'positive': 47167,
#   'negative': 10932,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 675,
#   'average_2weeks': 1,
#   'median_forever': 76,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 178},
#  '239140': {'appid': 239140,
#   'name': 'Dying Light',
#   'developer': 'Techland',
#   'publisher': 'Techland',
#   'score_rank': '',
#   'positive': 267809,
#   'negative': 13932,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2377,
#   'average_2weeks': 244,
#   'median_forever': 1192,
#   'median_2weeks': 209,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 5461},
#  '304050': {'appid': 304050,
#   'name': 'Trove',
#   'developer': 'Trion Worlds',
#   'publisher': 'Trion Worlds',
#   'score_rank': '',
#   'positive': 67708,
#   'negative': 15972,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2730,
#   'average_2weeks': 1512,
#   'median_forever': 187,
#   'median_2weeks': 1501,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2026},
#  '203160': {'appid': 203160,
#   'name': 'Tomb Raider',
#   'developer': 'Crystal Dynamics, Eidos-Montréal, Feral Interactive (Mac), Feral Interactive (Linux), Nixxes',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 196559,
#   'negative': 7754,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 759,
#   'average_2weeks': 94,
#   'median_forever': 460,
#   'median_2weeks': 113,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 1304},
#  '648800': {'appid': 648800,
#   'name': 'Raft',
#   'developer': 'Redbeet Interactive',
#   'publisher': 'Axolot Games',
#   'score_rank': '',
#   'positive': 132531,
#   'negative': 10203,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1333,
#   'average_2weeks': 197,
#   'median_forever': 724,
#   'median_2weeks': 175,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 4901},
#  '632360': {'appid': 632360,
#   'name': 'Risk of Rain 2',
#   'developer': 'Hopoo Games',
#   'publisher': 'Gearbox Publishing',
#   'score_rank': '',
#   'positive': 162333,
#   'negative': 5925,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3087,
#   'average_2weeks': 164,
#   'median_forever': 1434,
#   'median_2weeks': 144,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 6775},
#  '60': {'appid': 60,
#   'name': 'Ricochet',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 3581,
#   'negative': 823,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 34,
#   'average_2weeks': 0,
#   'median_forever': 6,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 4},
#  '255710': {'appid': 255710,
#   'name': 'Cities: Skylines',
#   'developer': 'Colossal Order Ltd.',
#   'publisher': 'Paradox Interactive',
#   'score_rank': '',
#   'positive': 163675,
#   'negative': 11971,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3900,
#   'average_2weeks': 384,
#   'median_forever': 821,
#   'median_2weeks': 78,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 14496},
#  '278360': {'appid': 278360,
#   'name': 'A Story About My Uncle',
#   'developer': 'Gone North Games',
#   'publisher': 'Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 25190,
#   'negative': 2235,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 624,
#   'average_2weeks': 2,
#   'median_forever': 214,
#   'median_2weeks': 2,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 15},
#  '439700': {'appid': 439700,
#   'name': 'Z1 Battle Royale: Test Server',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 1309,
#   'negative': 1167,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 64,
#   'average_2weeks': 0,
#   'median_forever': 19,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '360': {'appid': 360,
#   'name': 'Half-Life Deathmatch: Source',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 2250,
#   'negative': 747,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 674,
#   'average_2weeks': 0,
#   'median_forever': 10,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 8},
#  '588430': {'appid': 588430,
#   'name': 'Fallout Shelter',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 41259,
#   'negative': 5389,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 778,
#   'average_2weeks': 82,
#   'median_forever': 128,
#   'median_2weeks': 82,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1319},
#  '275850': {'appid': 275850,
#   'name': "No Man's Sky",
#   'developer': 'Hello Games',
#   'publisher': 'Hello Games',
#   'score_rank': '',
#   'positive': 157122,
#   'negative': 56842,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2578,
#   'average_2weeks': 249,
#   'median_forever': 1169,
#   'median_2weeks': 114,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 5684},
#  '273110': {'appid': 273110,
#   'name': 'Counter-Strike Nexon: Studio',
#   'developer': 'Valve Corporation, Nexon Korea Corporation',
#   'publisher': 'Nexon Korea Corporation',
#   'score_rank': '',
#   'positive': 25785,
#   'negative': 13257,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 928,
#   'average_2weeks': 652,
#   'median_forever': 65,
#   'median_2weeks': 652,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 465},
#  '365590': {'appid': 365590,
#   'name': 'Tom Clancy’s The Division',
#   'developer': 'Massive Entertainment',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 58310,
#   'negative': 26592,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5218,
#   'average_2weeks': 193,
#   'median_forever': 1711,
#   'median_2weeks': 193,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 1064},
#  '377160': {'appid': 377160,
#   'name': 'Fallout 4',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 208571,
#   'negative': 51910,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5692,
#   'average_2weeks': 930,
#   'median_forever': 1885,
#   'median_2weeks': 470,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 17608},
#  '10180': {'appid': 10180,
#   'name': 'Call of Duty: Modern Warfare 2',
#   'developer': 'Infinity Ward',
#   'publisher': 'Activision',
#   'score_rank': '',
#   'positive': 41141,
#   'negative': 3199,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 898,
#   'average_2weeks': 4,
#   'median_forever': 317,
#   'median_2weeks': 4,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 510},
#  '814380': {'appid': 814380,
#   'name': 'Sekiro: Shadows Die Twice - GOTY Edition',
#   'developer': 'FromSoftware',
#   'publisher': 'Activision (Excluding Japan and Asia), FromSoftware (Japan), 方块游戏 (Asia)',
#   'score_rank': '',
#   'positive': 148657,
#   'negative': 7994,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2267,
#   'average_2weeks': 356,
#   'median_forever': 1435,
#   'median_2weeks': 366,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 5844},
#  '466240': {'appid': 466240,
#   'name': 'Deceit',
#   'developer': 'World Makers',
#   'publisher': 'World Makers',
#   'score_rank': '',
#   'positive': 60787,
#   'negative': 16335,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 432,
#   'average_2weeks': 9,
#   'median_forever': 95,
#   'median_2weeks': 15,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 638},
#  '40': {'appid': 40,
#   'name': 'Deathmatch Classic',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1790,
#   'negative': 401,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 124,
#   'average_2weeks': 0,
#   'median_forever': 10,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 5},
#  '107410': {'appid': 107410,
#   'name': 'Arma 3',
#   'developer': 'Bohemia Interactive',
#   'publisher': 'Bohemia Interactive',
#   'score_rank': '',
#   'positive': 187075,
#   'negative': 19868,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 11606,
#   'average_2weeks': 770,
#   'median_forever': 1525,
#   'median_2weeks': 340,
#   'price': '749',
#   'initialprice': '2999',
#   'discount': '75',
#   'ccu': 12816},
#  '844870': {'appid': 844870,
#   'name': 'KurtzPel',
#   'developer': 'KOG',
#   'publisher': 'KOG',
#   'score_rank': '',
#   'positive': 21210,
#   'negative': 12429,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 440,
#   'average_2weeks': 0,
#   'median_forever': 87,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 336},
#  '30': {'appid': 30,
#   'name': 'Day of Defeat',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 4870,
#   'negative': 543,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 546,
#   'average_2weeks': 0,
#   'median_forever': 13,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 131},
#  '363970': {'appid': 363970,
#   'name': 'Clicker Heroes',
#   'developer': 'Playsaurus',
#   'publisher': 'Playsaurus',
#   'score_rank': '',
#   'positive': 50486,
#   'negative': 5613,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 6726,
#   'average_2weeks': 0,
#   'median_forever': 577,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3446},
#  '289070': {'appid': 289070,
#   'name': 'Sid Meier’s Civilization VI',
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 156807,
#   'negative': 32348,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 4320,
#   'average_2weeks': 525,
#   'median_forever': 1356,
#   'median_2weeks': 337,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 33660},
#  '813820': {'appid': 813820,
#   'name': 'Realm Royale',
#   'developer': 'Heroic Leap Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 37254,
#   'negative': 12627,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 720,
#   'average_2weeks': 123,
#   'median_forever': 119,
#   'median_2weeks': 234,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 966},
#  '374320': {'appid': 374320,
#   'name': 'DARK SOULS III',
#   'developer': 'FromSoftware, Inc.',
#   'publisher': 'FromSoftware, Inc., BANDAI NAMCO Entertainment',
#   'score_rank': '',
#   'positive': 274071,
#   'negative': 17072,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5042,
#   'average_2weeks': 214,
#   'median_forever': 1908,
#   'median_2weeks': 156,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 14571},
#  '44350': {'appid': 44350,
#   'name': 'GRID 2',
#   'developer': 'Codemasters Racing',
#   'publisher': 'Codemasters',
#   'score_rank': '',
#   'positive': 23277,
#   'negative': 4567,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 453,
#   'average_2weeks': 143,
#   'median_forever': 156,
#   'median_2weeks': 143,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 148},
#  '204360': {'appid': 204360,
#   'name': 'Castle Crashers',
#   'developer': 'The Behemoth',
#   'publisher': 'The Behemoth',
#   'score_rank': '',
#   'positive': 81748,
#   'negative': 3233,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 820,
#   'average_2weeks': 209,
#   'median_forever': 310,
#   'median_2weeks': 250,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 415},
#  '285800': {'appid': 285800,
#   'name': 'Braveland',
#   'developer': 'Tortuga Team',
#   'publisher': 'Tortuga Team',
#   'score_rank': '',
#   'positive': 2303,
#   'negative': 494,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1293,
#   'average_2weeks': 0,
#   'median_forever': 254,
#   'median_2weeks': 0,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 5},
#  '221380': {'appid': 221380,
#   'name': 'Age of Empires II (2013)',
#   'developer': 'Skybox Labs, Hidden Path Entertainment, Ensemble Studios, Forgotten Empires',
#   'publisher': 'Xbox Game Studios',
#   'score_rank': '',
#   'positive': 87535,
#   'negative': 4026,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2065,
#   'average_2weeks': 913,
#   'median_forever': 749,
#   'median_2weeks': 1174,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 4656},
#  '700330': {'appid': 700330,
#   'name': 'SCP: Secret Laboratory',
#   'developer': 'Northwood Studios',
#   'publisher': 'Northwood Studios',
#   'score_rank': '',
#   'positive': 112673,
#   'negative': 10323,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 988,
#   'average_2weeks': 391,
#   'median_forever': 57,
#   'median_2weeks': 336,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3253},
#  '242050': {'appid': 242050,
#   'name': 'Assassin’s Creed IV Black Flag',
#   'developer': 'Ubisoft Montreal',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 43446,
#   'negative': 5052,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1654,
#   'average_2weeks': 105,
#   'median_forever': 952,
#   'median_2weeks': 105,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 659},
#  '253710': {'appid': 253710,
#   'name': 'theHunter Classic',
#   'developer': 'Expansive Worlds, Avalanche Studios',
#   'publisher': 'Expansive Worlds, Avalanche Studios',
#   'score_rank': '',
#   'positive': 18994,
#   'negative': 16777,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 620,
#   'average_2weeks': 1572,
#   'median_forever': 50,
#   'median_2weeks': 1572,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1424},
#  '219740': {'appid': 219740,
#   'name': "Don't Starve",
#   'developer': 'Klei Entertainment',
#   'publisher': 'Klei Entertainment',
#   'score_rank': '',
#   'positive': 89270,
#   'negative': 2931,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1274,
#   'average_2weeks': 33,
#   'median_forever': 298,
#   'median_2weeks': 33,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 2538},
#  '219640': {'appid': 219640,
#   'name': 'Chivalry: Medieval Warfare',
#   'developer': 'Torn Banner Studios',
#   'publisher': 'Torn Banner Studios',
#   'score_rank': '',
#   'positive': 54678,
#   'negative': 11715,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1345,
#   'average_2weeks': 23,
#   'median_forever': 234,
#   'median_2weeks': 23,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 130},
#  '319630': {'appid': 319630,
#   'name': 'Life is Strange - Episode 1',
#   'developer': 'DONTNOD Entertainment, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'publisher': 'Square Enix, Feral interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 148492,
#   'negative': 5879,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 475,
#   'average_2weeks': 1,
#   'median_forever': 177,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 298},
#  '12120': {'appid': 12120,
#   'name': 'Grand Theft Auto: San Andreas',
#   'developer': 'Rockstar Games',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 64774,
#   'negative': 6110,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1025,
#   'average_2weeks': 333,
#   'median_forever': 173,
#   'median_2weeks': 333,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2218},
#  '109600': {'appid': 109600,
#   'name': 'Neverwinter',
#   'developer': 'Cryptic Studios',
#   'publisher': 'Perfect World Entertainment',
#   'score_rank': '',
#   'positive': 25904,
#   'negative': 7355,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1251,
#   'average_2weeks': 517,
#   'median_forever': 344,
#   'median_2weeks': 517,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1743},
#  '387990': {'appid': 387990,
#   'name': 'Scrap Mechanic',
#   'developer': 'Axolot Games',
#   'publisher': 'Axolot Games',
#   'score_rank': '',
#   'positive': 72968,
#   'negative': 5980,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2189,
#   'average_2weeks': 189,
#   'median_forever': 1099,
#   'median_2weeks': 167,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 2545},
#  '863550': {'appid': 863550,
#   'name': 'HITMAN 2',
#   'developer': 'IO Interactive A/S',
#   'publisher': 'IO Interactive A/S',
#   'score_rank': '',
#   'positive': 55431,
#   'negative': 5463,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
# ...
#   'developer': 'Strategy Labs',
#   'publisher': 'PlayWay S.A., CreativeForge Games',
#   'score_rank': '',
#   'positive': 2776,
#   'negative': 904,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 19},
#  '977950': {'appid': 977950,
#   'name': 'A Dance of Fire and Ice',
#   'developer': '7th Beat Games',
#   'publisher': '7th Beat Games, indienova',
#   'score_rank': '',
#   'positive': 28691,
#   'negative': 1949,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1343,
#   'average_2weeks': 54,
#   'median_forever': 187,
#   'median_2weeks': 69,
#   'price': '599',
#   'initialprice': '599',
#   'discount': '0',
#   'ccu': 3282},
#  '24720': {'appid': 24720,
#   'name': 'SPORE Galactic Adventures',
#   'developer': 'EA - Maxis',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 4249,
#   'negative': 628,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 547,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 190},
#  '383120': {'appid': 383120,
#   'name': 'Empyrion - Galactic Survival',
#   'developer': 'Eleon Game Studios',
#   'publisher': 'Eleon Game Studios',
#   'score_rank': '',
#   'positive': 20982,
#   'negative': 4936,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 4972,
#   'average_2weeks': 155,
#   'median_forever': 831,
#   'median_2weeks': 155,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 1983},
#  '553640': {'appid': 553640,
#   'name': 'ICEY',
#   'developer': 'FantaBlade Network',
#   'publisher': 'XD',
#   'score_rank': '',
#   'positive': 19602,
#   'negative': 1922,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 220,
#   'average_2weeks': 0,
#   'median_forever': 159,
#   'median_2weeks': 0,
#   'price': '1099',
#   'initialprice': '1099',
#   'discount': '0',
#   'ccu': 17},
#  '479130': {'appid': 479130,
#   'name': 'ESEA',
#   'developer': 'ESEA',
#   'publisher': 'ESEA',
#   'score_rank': '',
#   'positive': 3016,
#   'negative': 1109,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 429,
#   'average_2weeks': 58,
#   'median_forever': 11,
#   'median_2weeks': 58,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 593},
#  '304650': {'appid': 304650,
#   'name': 'SUNLESS SEA',
#   'developer': 'Failbetter Games',
#   'publisher': 'Failbetter Games',
#   'score_rank': '',
#   'positive': 6774,
#   'negative': 1346,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1247,
#   'average_2weeks': 42,
#   'median_forever': 335,
#   'median_2weeks': 42,
#   'price': '1899',
#   'initialprice': '1899',
#   'discount': '0',
#   'ccu': 74},
#  '522570': {'appid': 522570,
#   'name': 'The Last Hope',
#   'developer': 'Atomic Fabrik, Cristian Manolachi',
#   'publisher': 'Atomic Fabrik, Cristian Manolachi',
#   'score_rank': '',
#   'positive': 324,
#   'negative': 542,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 202,
#   'average_2weeks': 0,
#   'median_forever': 233,
#   'median_2weeks': 0,
#   'price': '99',
#   'initialprice': '99',
#   'discount': '0',
#   'ccu': 0},
#  '327030': {'appid': 327030,
#   'name': 'Worms W.M.D',
#   'developer': 'Team17',
#   'publisher': 'Team17',
#   'score_rank': '',
#   'positive': 6095,
#   'negative': 1218,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 431,
#   'average_2weeks': 7,
#   'median_forever': 241,
#   'median_2weeks': 7,
#   'price': '599',
#   'initialprice': '2999',
#   'discount': '80',
#   'ccu': 440},
#  '34830': {'appid': 34830,
#   'name': 'Sniper: Ghost Warrior',
#   'developer': 'City Interactive',
#   'publisher': 'CI Games',
#   'score_rank': '',
#   'positive': 3577,
#   'negative': 2765,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 314,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '159',
#   'initialprice': '799',
#   'discount': '80',
#   'ccu': 51},
#  '242640': {'appid': 242640,
#   'name': 'Styx: Master of Shadows',
#   'developer': 'Cyanide Studio',
#   'publisher': 'Cyanide Studio, Nacon',
#   'score_rank': '',
#   'positive': 6535,
#   'negative': 1370,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 225,
#   'average_2weeks': 0,
#   'median_forever': 130,
#   'median_2weeks': 0,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 60},
#  '1259970': {'appid': 1259970,
#   'name': 'eFootball PES 2021 SEASON UPDATE',
#   'developer': 'Konami Digital Entertainment',
#   'publisher': 'Konami Digital Entertainment',
#   'score_rank': '',
#   'positive': 23235,
#   'negative': 8082,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 2131,
#   'average_2weeks': 202,
#   'median_forever': 808,
#   'median_2weeks': 237,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 9746},
#  '268870': {'appid': 268870,
#   'name': 'Satellite Reign',
#   'developer': '5 Lives Studios',
#   'publisher': '5 Lives Studios',
#   'score_rank': '',
#   'positive': 3369,
#   'negative': 1386,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 314,
#   'average_2weeks': 0,
#   'median_forever': 266,
#   'median_2weeks': 0,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 14},
#  '264200': {'appid': 264200,
#   'name': 'One Finger Death Punch',
#   'developer': 'Silver Dollar Games',
#   'publisher': 'Silver Dollar Games',
#   'score_rank': '',
#   'positive': 15467,
#   'negative': 297,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 468,
#   'average_2weeks': 0,
#   'median_forever': 164,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 17},
#  '434570': {'appid': 434570,
#   'name': 'Blood and Bacon',
#   'developer': 'Big Corporation',
#   'publisher': 'Grunge Games LTD',
#   'score_rank': '',
#   'positive': 25499,
#   'negative': 1336,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 211,
#   'average_2weeks': 23,
#   'median_forever': 148,
#   'median_2weeks': 31,
#   'price': '99',
#   'initialprice': '99',
#   'discount': '0',
#   'ccu': 66},
#  '1139900': {'appid': 1139900,
#   'name': 'Ghostrunner',
#   'developer': 'One More Level, 3D Realms, Slipgate Ironworks™, All in! Games',
#   'publisher': '505 Games',
#   'score_rank': '',
#   'positive': 31764,
#   'negative': 2938,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 381,
#   'average_2weeks': 0,
#   'median_forever': 320,
#   'median_2weeks': 0,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 360},
#  '610080': {'appid': 610080,
#   'name': 'Realm Grinder',
#   'developer': 'Divine Games',
#   'publisher': 'Kongregate',
#   'score_rank': '',
#   'positive': 4664,
#   'negative': 708,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 4646,
#   'average_2weeks': 47,
#   'median_forever': 326,
#   'median_2weeks': 47,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1182},
#  '513780': {'appid': 513780,
#   'name': 'Turbo Pug DX',
#   'developer': 'SnowFlame, Back To Basics Gaming',
#   'publisher': 'Back To Basics Gaming',
#   'score_rank': '',
#   'positive': 1326,
#   'negative': 377,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 174,
#   'average_2weeks': 0,
#   'median_forever': 233,
#   'median_2weeks': 0,
#   'price': '99',
#   'initialprice': '99',
#   'discount': '0',
#   'ccu': 0},
#  '394310': {'appid': 394310,
#   'name': 'Punch Club',
#   'developer': 'Lazy Bear Games',
#   'publisher': 'tinyBuild',
#   'score_rank': '',
#   'positive': 8187,
#   'negative': 2051,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 465,
#   'average_2weeks': 0,
#   'median_forever': 435,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 42},
#  '606150': {'appid': 606150,
#   'name': 'Moonlighter',
#   'developer': 'Digital Sun',
#   'publisher': '11 bit studios',
#   'score_rank': '',
#   'positive': 10114,
#   'negative': 2032,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 528,
#   'average_2weeks': 0,
#   'median_forever': 422,
#   'median_2weeks': 0,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 84},
#  '282800': {'appid': 282800,
#   'name': '100% Orange Juice',
#   'developer': 'Orange_Juice',
#   'publisher': 'Fruitbat Factory',
#   'score_rank': '',
#   'positive': 19831,
#   'negative': 1494,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1598,
#   'average_2weeks': 219,
#   'median_forever': 135,
#   'median_2weeks': 219,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 275},
#  '575110': {'appid': 575110,
#   'name': 'Magic Lantern',
#   'developer': 'Parovoz Animation Studio',
#   'publisher': 'Interactive Moolt',
#   'score_rank': '',
#   'positive': 24,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 58,
#   'average_2weeks': 0,
#   'median_forever': 15,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '517630': {'appid': 517630,
#   'name': 'Just Cause 4 Reloaded',
#   'developer': 'Avalanche Studios',
#   'publisher': 'Square Enix',
#   'score_rank': '',
#   'positive': 12779,
#   'negative': 8517,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 750,
#   'average_2weeks': 542,
#   'median_forever': 568,
#   'median_2weeks': 542,
#   'price': '6903',
#   'initialprice': '6903',
#   'discount': '0',
#   'ccu': 292},
#  '397720': {'appid': 397720,
#   'name': 'Romance of the Three Kingdoms Maker / 三国志ツクール',
#   'developer': 'KOEI TECMO GAMES CO., LTD.',
#   'publisher': 'KOEI TECMO GAMES CO., LTD.',
#   'score_rank': '',
#   'positive': 169,
#   'negative': 92,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1783,
#   'average_2weeks': 0,
#   'median_forever': 7,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 7},
#  '265550': {'appid': 265550,
#   'name': 'Dead Rising 3 Apocalypse Edition',
#   'developer': 'Capcom Game Studio Vancouver',
#   'publisher': 'Capcom',
#   'score_rank': '',
#   'positive': 10437,
#   'negative': 3711,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 652,
#   'average_2weeks': 611,
#   'median_forever': 432,
#   'median_2weeks': 611,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 95},
#  '1520': {'appid': 1520,
#   'name': 'DEFCON',
#   'developer': 'Introversion Software',
#   'publisher': 'Introversion Software',
#   'score_rank': '',
#   'positive': 2773,
#   'negative': 435,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 328,
#   'average_2weeks': 0,
#   'median_forever': 46,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 24},
#  '991780': {'appid': 991780,
#   'name': 'Notes of Soul',
#   'developer': '（Hong Kong）GKD Game Studio',
#   'publisher': '（Hong Kong）GKD Game Studio',
#   'score_rank': '',
#   'positive': 16124,
#   'negative': 4452,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 10978,
#   'average_2weeks': 0,
#   'median_forever': 12107,
#   'median_2weeks': 0,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 297},
#  '323470': {'appid': 323470,
#   'name': 'DRAGON BALL XENOVERSE',
#   'developer': 'DIMPS',
#   'publisher': 'BANDAI NAMCO Entertainment',
#   'score_rank': '',
#   'positive': 13948,
#   'negative': 1809,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1082,
#   'average_2weeks': 0,
#   'median_forever': 875,
#   'median_2weeks': 0,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 40},
#  '414530': {'appid': 414530,
#   'name': 'Skyforge',
#   'developer': 'Allods Team',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 2268,
#   'negative': 1587,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 955,
#   'average_2weeks': 0,
#   'median_forever': 228,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 116},
#  '301750': {'appid': 301750,
#   'name': 'RADical ROACH Remastered',
#   'developer': 'DL Softworks',
#   'publisher': 'DL Softworks',
#   'score_rank': '',
#   'positive': 581,
#   'negative': 496,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 321,
#   'average_2weeks': 0,
#   'median_forever': 303,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1058020': {'appid': 1058020,
#   'name': 'STAR WARS Battlefront (Classic, 2004)',
#   'developer': 'Pandemic Studios',
#   'publisher': 'Lucasfilm, LucasArts, Disney',
#   'score_rank': '',
#   'positive': 2715,
#   'negative': 101,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 837,
#   'average_2weeks': 0,
#   'median_forever': 799,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 45},
#  '39000': {'appid': 39000,
#   'name': 'Moonbase Alpha',
#   'developer': 'Virtual Heroes, Army Game Studio',
#   'publisher': 'NASA',
#   'score_rank': '',
#   'positive': 10983,
#   'negative': 1220,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 53,
#   'average_2weeks': 1,
#   'median_forever': 41,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 6},
#  '285160': {'appid': 285160,
#   'name': 'LEGO The Hobbit',
#   'developer': "Traveller's Tales, Feral Interactive (Mac)",
#   'publisher': 'Warner Bros. Interactive Entertainment, Feral Interactive (Mac)',
#   'score_rank': '',
#   'positive': 5775,
#   'negative': 1409,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 312,
#   'average_2weeks': 0,
#   'median_forever': 104,
#   'median_2weeks': 0,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 124},
#  '249050': {'appid': 249050,
#   'name': 'Dungeon of the ENDLESS',
#   'developer': 'AMPLITUDE Studios',
#   'publisher': 'SEGA',
#   'score_rank': '',
#   'positive': 9652,
#   'negative': 1320,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 541,
#   'average_2weeks': 0,
#   'median_forever': 285,
#   'median_2weeks': 0,
#   'price': '1199',
#   'initialprice': '1199',
#   'discount': '0',
#   'ccu': 78},
#  '341800': {'appid': 341800,
#   'name': 'Keep Talking and Nobody Explodes',
#   'developer': 'Steel Crate Games',
#   'publisher': 'Steel Crate Games',
#   'score_rank': '',
#   'positive': 9709,
#   'negative': 201,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 495,
#   'average_2weeks': 0,
#   'median_forever': 181,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 86},
#  '454650': {'appid': 454650,
#   'name': 'DRAGON BALL XENOVERSE 2',
#   'developer': 'QLOC, DIMPS',
#   'publisher': 'BANDAI NAMCO Entertainment',
#   'score_rank': '',
#   'positive': 25390,
#   'negative': 3758,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 3517,
#   'average_2weeks': 234,
#   'median_forever': 1788,
#   'median_2weeks': 234,
#   'price': '4999',
#   'initialprice': '4999',
#   'discount': '0',
#   'ccu': 1094},
#  '1030830': {'appid': 1030830,
#   'name': 'Mafia II: Definitive Edition',
#   'developer': 'Hangar 13, D3T',
#   'publisher': '2K',
#   'score_rank': '',
#   'positive': 8561,
#   'negative': 3932,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 488,
#   'average_2weeks': 0,
#   'median_forever': 274,
#   'median_2weeks': 0,
#   'price': '989',
#   'initialprice': '2999',
#   'discount': '67',
#   'ccu': 619},
#  '495910': {'appid': 495910,
#   'name': 'Dungeon Fighter Online',
#   'developer': 'Neople',
#   'publisher': 'Neople',
#   'score_rank': '',
#   'positive': 2752,
#   'negative': 1587,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 434,
#   'average_2weeks': 1,
#   'median_forever': 253,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 308}}

# %%
import steamspypi

data_request = dict()
data_request['request'] = 'top100in2weeks'

data = steamspypi.download(data_request)
data
# Out:
# {'570': {'appid': 570,
#   'name': 'Dota 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1343537,
#   'negative': 260064,
#   'userscore': 0,
#   'owners': '100,000,000 .. 200,000,000',
#   'average_forever': 33549,
#   'average_2weeks': 1553,
#   'median_forever': 1037,
#   'median_2weeks': 795,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 569616},
#  '730': {'appid': 730,
#   'name': 'Counter-Strike: Global Offensive',
#   'developer': 'Valve, Hidden Path Entertainment',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 5296582,
#   'negative': 713258,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 27948,
#   'average_2weeks': 896,
#   'median_forever': 5974,
#   'median_2weeks': 340,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 695153},
#  '578080': {'appid': 578080,
#   'name': 'PUBG: BATTLEGROUNDS',
#   'developer': 'KRAFTON, Inc.',
#   'publisher': 'KRAFTON, Inc.',
#   'score_rank': '',
#   'positive': 1020533,
#   'negative': 834227,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 24119,
#   'average_2weeks': 455,
#   'median_forever': 10045,
#   'median_2weeks': 166,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 286942},
#  '440': {'appid': 440,
#   'name': 'Team Fortress 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 771213,
#   'negative': 51672,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 9077,
#   'average_2weeks': 2505,
#   'median_forever': 365,
#   'median_2weeks': 237,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 103460},
#  '304930': {'appid': 304930,
#   'name': 'Unturned',
#   'developer': 'Smartly Dressed Games',
#   'publisher': 'Smartly Dressed Games',
#   'score_rank': '',
#   'positive': 416405,
#   'negative': 39089,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5096,
#   'average_2weeks': 1875,
#   'median_forever': 339,
#   'median_2weeks': 413,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 29490},
#  '230410': {'appid': 230410,
#   'name': 'Warframe',
#   'developer': 'Digital Extremes',
#   'publisher': 'Digital Extremes',
#   'score_rank': '',
#   'positive': 413961,
#   'negative': 43642,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 9511,
#   'average_2weeks': 1415,
#   'median_forever': 403,
#   'median_2weeks': 628,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 52688},
#  '271590': {'appid': 271590,
#   'name': 'Grand Theft Auto V',
#   'developer': 'Rockstar North',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 1035169,
#   'negative': 200049,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 12857,
#   'average_2weeks': 447,
#   'median_forever': 6209,
#   'median_2weeks': 101,
#   'price': '2998',
#   'initialprice': '2998',
#   'discount': '0',
#   'ccu': 89418},
#  '550': {'appid': 550,
#   'name': 'Left 4 Dead 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 541252,
#   'negative': 14737,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 2089,
#   'average_2weeks': 139,
#   'median_forever': 580,
#   'median_2weeks': 55,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 15718},
#  '252490': {'appid': 252490,
#   'name': 'Rust',
#   'developer': 'Facepunch Studios',
#   'publisher': 'Facepunch Studios',
#   'score_rank': '',
#   'positive': 605718,
#   'negative': 92525,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 19351,
#   'average_2weeks': 1028,
#   'median_forever': 3117,
#   'median_2weeks': 640,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 73507},
#  '291550': {'appid': 291550,
#   'name': 'Brawlhalla',
#   'developer': 'Blue Mammoth Games',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 213331,
#   'negative': 39162,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1270,
#   'average_2weeks': 271,
#   'median_forever': 185,
#   'median_2weeks': 63,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 18878},
#  '1063730': {'appid': 1063730,
#   'name': 'New World',
#   'developer': 'Amazon Games',
#   'publisher': 'Amazon Games',
#   'score_rank': '',
#   'positive': 127666,
#   'negative': 45268,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5421,
#   'average_2weeks': 1717,
#   'median_forever': 3404,
#   'median_2weeks': 802,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 159838},
#  '4000': {'appid': 4000,
#   'name': "Garry's Mod",
#   'developer': 'Facepunch Studios',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 732278,
#   'negative': 25866,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 8706,
#   'average_2weeks': 602,
#   'median_forever': 1265,
#   'median_2weeks': 114,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 26876},
#  '359550': {'appid': 359550,
#   'name': "Tom Clancy's Rainbow Six Siege",
#   'developer': 'Ubisoft Montreal',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 867852,
#   'negative': 125001,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 14230,
#   'average_2weeks': 450,
#   'median_forever': 3265,
#   'median_2weeks': 161,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 44619},
#  '1172470': {'appid': 1172470,
#   'name': 'Apex Legends',
#   'developer': 'Respawn Entertainment',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 295221,
#   'negative': 46310,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 4870,
#   'average_2weeks': 862,
#   'median_forever': 713,
#   'median_2weeks': 451,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 199528},
#  '945360': {'appid': 945360,
#   'name': 'Among Us',
#   'developer': 'Innersloth',
#   'publisher': 'Innersloth',
#   'score_rank': '',
#   'positive': 543747,
#   'negative': 44084,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1310,
#   'average_2weeks': 114,
#   'median_forever': 690,
#   'median_2weeks': 66,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 13065},
#  '236390': {'appid': 236390,
#   'name': 'War Thunder',
#   'developer': 'Gaijin Entertainment',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 204398,
#   'negative': 54002,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5576,
#   'average_2weeks': 1206,
#   'median_forever': 438,
#   'median_2weeks': 638,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31163},
#  '340': {'appid': 340,
#   'name': 'Half-Life 2: Lost Coast',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 8511,
#   'negative': 1217,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 221,
#   'average_2weeks': 0,
#   'median_forever': 22,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 15},
#  '218620': {'appid': 218620,
#   'name': 'PAYDAY 2',
#   'developer': 'OVERKILL - a Starbreeze Studio.',
#   'publisher': 'Starbreeze Publishing AB',
#   'score_rank': '',
#   'positive': 484415,
#   'negative': 61402,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 4810,
#   'average_2weeks': 1599,
#   'median_forever': 611,
#   'median_2weeks': 147,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 25958},
#  '238960': {'appid': 238960,
#   'name': 'Path of Exile',
#   'developer': 'Grinding Gear Games',
#   'publisher': 'Grinding Gear Games',
#   'score_rank': '',
#   'positive': 157410,
#   'negative': 15981,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5977,
#   'average_2weeks': 1920,
#   'median_forever': 464,
#   'median_2weeks': 2275,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 46035},
#  '1085660': {'appid': 1085660,
#   'name': 'Destiny 2',
#   'developer': 'Bungie',
#   'publisher': 'Bungie',
#   'score_rank': '',
#   'positive': 354430,
#   'negative': 64735,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8018,
#   'average_2weeks': 1028,
#   'median_forever': 397,
#   'median_2weeks': 827,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 44827},
#  '10': {'appid': 10,
#   'name': 'Counter-Strike',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 184098,
#   'negative': 4788,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 10209,
#   'average_2weeks': 733,
#   'median_forever': 217,
#   'median_2weeks': 124,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 14562},
#  '892970': {'appid': 892970,
#   'name': 'Valheim',
#   'developer': 'Iron Gate AB',
#   'publisher': ' Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 266535,
#   'negative': 12637,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2433,
#   'average_2weeks': 584,
#   'median_forever': 1417,
#   'median_2weeks': 525,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 17996},
#  '444090': {'appid': 444090,
#   'name': 'Paladins',
#   'developer': 'Evil Mojo Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 269165,
#   'negative': 44391,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2841,
#   'average_2weeks': 561,
#   'median_forever': 488,
#   'median_2weeks': 426,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9221},
#  '272060': {'appid': 272060,
#   'name': 'Serena',
#   'developer': 'Senscape',
#   'publisher': 'Senscape',
#   'score_rank': '',
#   'positive': 4844,
#   'negative': 1425,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 817,
#   'average_2weeks': 0,
#   'median_forever': 5,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4},
#  '431960': {'appid': 431960,
#   'name': 'Wallpaper Engine',
#   'developer': 'Wallpaper Engine Team',
#   'publisher': 'Wallpaper Engine Team',
#   'score_rank': '',
#   'positive': 419756,
#   'negative': 8887,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2794,
#   'average_2weeks': 198,
#   'median_forever': 669,
#   'median_2weeks': 11,
#   'price': '399',
#   'initialprice': '399',
#   'discount': '0',
#   'ccu': 60865},
#  '49520': {'appid': 49520,
#   'name': 'Borderlands 2',
#   'developer': 'Gearbox Software, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 237581,
#   'negative': 16170,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3430,
#   'average_2weeks': 386,
#   'median_forever': 1007,
#   'median_2weeks': 557,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 3563},
#  '1097150': {'appid': 1097150,
#   'name': 'Fall Guys: Ultimate Knockout',
#   'developer': 'Mediatonic',
#   'publisher': '',
#   'score_rank': '',
#   'positive': 330623,
#   'negative': 66978,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 956,
#   'average_2weeks': 73,
#   'median_forever': 465,
#   'median_2weeks': 31,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 5240},
#  '1091500': {'appid': 1091500,
#   'name': 'Cyberpunk 2077',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 333656,
#   'negative': 109053,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3240,
#   'average_2weeks': 313,
#   'median_forever': 2380,
#   'median_2weeks': 183,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 8893},
#  '227940': {'appid': 227940,
#   'name': 'Heroes & Generals',
#   'developer': 'RETO MOTO',
#   'publisher': 'RETO MOTO',
#   'score_rank': '',
#   'positive': 91549,
#   'negative': 43619,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 974,
#   'average_2weeks': 276,
#   'median_forever': 87,
#   'median_2weeks': 330,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2214},
#  '292030': {'appid': 292030,
#   'name': 'The Witcher 3: Wild Hunt',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 550555,
#   'negative': 11651,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3040,
#   'average_2weeks': 349,
#   'median_forever': 889,
#   'median_2weeks': 103,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 16602},
#  '381210': {'appid': 381210,
#   'name': 'Dead by Daylight',
#   'developer': 'Behaviour Interactive Inc.',
#   'publisher': 'Behaviour Interactive Inc.',
#   'score_rank': '',
#   'positive': 445436,
#   'negative': 98688,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 7944,
#   'average_2weeks': 663,
#   'median_forever': 1178,
#   'median_2weeks': 352,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 47088},
#  '105600': {'appid': 105600,
#   'name': 'Terraria',
#   'developer': 'Re-Logic',
#   'publisher': 'Re-Logic',
#   'score_rank': '',
#   'positive': 816680,
#   'negative': 17412,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8001,
#   'average_2weeks': 436,
#   'median_forever': 2581,
#   'median_2weeks': 142,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 28709},
#  '291480': {'appid': 291480,
#   'name': 'Warface',
#   'developer': 'MY.GAMES',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 49547,
#   'negative': 23104,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 615,
#   'average_2weeks': 94,
#   'median_forever': 111,
#   'median_2weeks': 148,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2621},
#  '1468810': {'appid': 1468810,
#   'name': '鬼谷八荒 Tale of Immortal',
#   'developer': '鬼谷工作室',
#   'publisher': '鬼谷工作室, Lightning Games',
#   'score_rank': '',
#   'positive': 102648,
#   'negative': 15717,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3048,
#   'average_2weeks': 1583,
#   'median_forever': 1907,
#   'median_2weeks': 857,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 18346},
#  '552990': {'appid': 552990,
#   'name': 'World of Warships',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 72446,
#   'negative': 18099,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1775,
#   'average_2weeks': 421,
#   'median_forever': 181,
#   'median_2weeks': 788,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9887},
#  '301520': {'appid': 301520,
#   'name': 'Robocraft',
#   'developer': 'Freejam',
#   'publisher': 'Freejam',
#   'score_rank': '',
#   'positive': 85926,
#   'negative': 32316,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1299,
#   'average_2weeks': 239,
#   'median_forever': 184,
#   'median_2weeks': 273,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 291},
#  '620': {'appid': 620,
#   'name': 'Portal 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 265305,
#   'negative': 3236,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 900,
#   'average_2weeks': 137,
#   'median_forever': 479,
#   'median_2weeks': 196,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 1532},
#  '227300': {'appid': 227300,
#   'name': 'Euro Truck Simulator 2',
#   'developer': 'SCS Software',
#   'publisher': 'SCS Software',
#   'score_rank': '',
#   'positive': 470322,
#   'negative': 11536,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5461,
#   'average_2weeks': 391,
#   'median_forever': 1587,
#   'median_2weeks': 190,
#   'price': '499',
#   'initialprice': '1999',
#   'discount': '75',
#   'ccu': 36135},
#  '550650': {'appid': 550650,
#   'name': 'Black Squad',
#   'developer': 'VALOFE, NS STUDIO',
#   'publisher': 'VALOFE',
#   'score_rank': '',
#   'positive': 59207,
#   'negative': 17991,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1099,
#   'average_2weeks': 21,
#   'median_forever': 81,
#   'median_2weeks': 26,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1266},
#  '320': {'appid': 320,
#   'name': 'Half-Life 2: Deathmatch',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 9020,
#   'negative': 1005,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1043,
#   'average_2weeks': 0,
#   'median_forever': 39,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 234},
#  '240': {'appid': 240,
#   'name': 'Counter-Strike: Source',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 124196,
#   'negative': 5011,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 6125,
#   'average_2weeks': 190,
#   'median_forever': 435,
#   'median_2weeks': 270,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 5080},
#  '755790': {'appid': 755790,
#   'name': 'Ring of Elysium',
#   'developer': 'Aurora Studio',
#   'publisher': 'TCH Scarlet Limited',
#   'score_rank': '',
#   'positive': 73617,
#   'negative': 25217,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 662,
#   'average_2weeks': 21,
#   'median_forever': 109,
#   'median_2weeks': 28,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1380},
#  '252950': {'appid': 252950,
#   'name': 'Rocket League',
#   'developer': 'Psyonix LLC',
#   'publisher': 'Psyonix LLC',
#   'score_rank': '',
#   'positive': 479646,
#   'negative': 59784,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 14707,
#   'average_2weeks': 624,
#   'median_forever': 2553,
#   'median_2weeks': 384,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 32799},
#  '386360': {'appid': 386360,
#   'name': 'SMITE',
#   'developer': 'Titan Forge Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 74093,
#   'negative': 17977,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 4670,
#   'average_2weeks': 375,
#   'median_forever': 199,
#   'median_2weeks': 284,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 17090},
#  '477160': {'appid': 477160,
#   'name': 'Human: Fall Flat',
#   'developer': 'No Brakes Games',
#   'publisher': 'Curve Games',
#   'score_rank': '',
#   'positive': 142048,
#   'negative': 8211,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 746,
#   'average_2weeks': 225,
#   'median_forever': 350,
#   'median_2weeks': 64,
#   'price': '679',
#   'initialprice': '1999',
#   'discount': '66',
#   'ccu': 6853},
#  '322330': {'appid': 322330,
#   'name': "Don't Starve Together",
#   'developer': 'Klei Entertainment',
#   'publisher': 'Klei Entertainment',
#   'score_rank': '',
#   'positive': 280268,
#   'negative': 11175,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2335,
#   'average_2weeks': 341,
#   'median_forever': 483,
#   'median_2weeks': 120,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 20773},
#  '433850': {'appid': 433850,
#   'name': 'Z1 Battle Royale',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 115763,
#   'negative': 93225,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2273,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 101},
#  '413150': {'appid': 413150,
#   'name': 'Stardew Valley',
#   'developer': 'ConcernedApe',
#   'publisher': 'ConcernedApe',
#   'score_rank': '',
#   'positive': 396755,
#   'negative': 8153,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3224,
#   'average_2weeks': 293,
#   'median_forever': 1562,
#   'median_2weeks': 189,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 25123},
#  '275390': {'appid': 275390,
#   'name': 'Guacamelee! Super Turbo Championship Edition',
#   'developer': 'DrinkBox Studios',
#   'publisher': 'DrinkBox Studios',
#   'score_rank': '',
#   'positive': 5238,
#   'negative': 420,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 146,
#   'average_2weeks': 0,
#   'median_forever': 66,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 18},
#  '739630': {'appid': 739630,
#   'name': 'Phasmophobia',
#   'developer': 'Kinetic Games',
#   'publisher': 'Kinetic Games',
#   'score_rank': '',
#   'positive': 342985,
#   'negative': 10064,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1315,
#   'average_2weeks': 133,
#   'median_forever': 741,
#   'median_2weeks': 92,
#   'price': '1399',
#   'initialprice': '1399',
#   'discount': '0',
#   'ccu': 15264},
#  '220': {'appid': 220,
#   'name': 'Half-Life 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 128402,
#   'negative': 3480,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 806,
#   'average_2weeks': 229,
#   'median_forever': 409,
#   'median_2weeks': 229,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 680},
#  '346110': {'appid': 346110,
#   'name': 'ARK: Survival Evolved',
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'publisher': 'Studio Wildcard',
#   'score_rank': '',
#   'positive': 383425,
#   'negative': 90947,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 11724,
#   'average_2weeks': 1494,
#   'median_forever': 1663,
#   'median_2weeks': 1028,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 42817},
#  '130': {'appid': 130,
#   'name': 'Half-Life: Blue Shift',
#   'developer': 'Gearbox Software',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 8898,
#   'negative': 867,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 819,
#   'average_2weeks': 0,
#   'median_forever': 92,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 29},
#  '417910': {'appid': 417910,
#   'name': 'Street Warriors Online',
#   'developer': 'Crazy Rocks Studios',
#   'publisher': 'Crazy Rocks Studios',
#   'score_rank': '',
#   'positive': 973,
#   'negative': 710,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 61,
#   'average_2weeks': 0,
#   'median_forever': 52,
#   'median_2weeks': 0,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 0},
#  '242760': {'appid': 242760,
#   'name': 'The Forest',
#   'developer': 'Endnight Games Ltd',
#   'publisher': 'Endnight Games Ltd',
#   'score_rank': '',
#   'positive': 298737,
#   'negative': 15961,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1747,
#   'average_2weeks': 164,
#   'median_forever': 859,
#   'median_2weeks': 153,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 6514},
#  '582010': {'appid': 582010,
#   'name': 'Monster Hunter: World',
#   'developer': 'CAPCOM Co., Ltd.',
#   'publisher': 'CAPCOM Co., Ltd.',
#   'score_rank': '',
#   'positive': 284082,
#   'negative': 51548,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8749,
#   'average_2weeks': 636,
#   'median_forever': 2223,
#   'median_2weeks': 492,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 18603},
#  '400': {'appid': 400,
#   'name': 'Portal',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 94820,
#   'negative': 1545,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 398,
#   'average_2weeks': 14,
#   'median_forever': 167,
#   'median_2weeks': 19,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 323},
#  '8930': {'appid': 8930,
#   'name': "Sid Meier's Civilization V",
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 172823,
#   'negative': 6897,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 7463,
#   'average_2weeks': 629,
#   'median_forever': 2830,
#   'median_2weeks': 567,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 17425},
#  '532210': {'appid': 532210,
#   'name': 'Life is Strange 2',
#   'developer': 'DONTNOD Entertainment, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 21094,
#   'negative': 3885,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 412,
#   'average_2weeks': 0,
#   'median_forever': 209,
#   'median_2weeks': 0,
#   'price': '3196',
#   'initialprice': '3196',
#   'discount': '0',
#   'ccu': 161},
#  '218230': {'appid': 218230,
#   'name': 'PlanetSide 2',
#   'developer': 'Rogue Planet Games',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 52096,
#   'negative': 11413,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1665,
#   'average_2weeks': 572,
#   'median_forever': 157,
#   'median_2weeks': 848,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1520},
#  '72850': {'appid': 72850,
#   'name': 'The Elder Scrolls V: Skyrim',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 288909,
#   'negative': 15745,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 7073,
#   'average_2weeks': 177,
#   'median_forever': 3213,
#   'median_2weeks': 262,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 6171},
#  '70': {'appid': 70,
#   'name': 'Half-Life',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 64692,
#   'negative': 2339,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1888,
#   'average_2weeks': 25,
#   'median_forever': 154,
#   'median_2weeks': 25,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 491},
#  '444200': {'appid': 444200,
#   'name': 'World of Tanks Blitz',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 74412,
#   'negative': 18438,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2659,
#   'average_2weeks': 1174,
#   'median_forever': 151,
#   'median_2weeks': 1640,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31091},
#  '80': {'appid': 80,
#   'name': 'Counter-Strike: Condition Zero',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 18055,
#   'negative': 1766,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 857,
#   'average_2weeks': 0,
#   'median_forever': 44,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 440},
#  '261550': {'appid': 261550,
#   'name': 'Mount & Blade II: Bannerlord',
#   'developer': 'TaleWorlds Entertainment',
#   'publisher': 'TaleWorlds Entertainment',
#   'score_rank': '',
#   'positive': 150188,
#   'negative': 22240,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5220,
#   'average_2weeks': 656,
#   'median_forever': 3571,
#   'median_2weeks': 720,
#   'price': '4999',
#   'initialprice': '4999',
#   'discount': '0',
#   'ccu': 14339},
#  '251570': {'appid': 251570,
#   'name': '7 Days to Die',
#   'developer': 'The Fun Pimps',
#   'publisher': 'The Fun Pimps Entertainment LLC',
#   'score_rank': '',
#   'positive': 164552,
#   'negative': 23410,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5037,
#   'average_2weeks': 747,
#   'median_forever': 1310,
#   'median_2weeks': 416,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 17585},
#  '96000': {'appid': 96000,
#   'name': 'The Tiny Bang Story',
#   'developer': 'Colibri Games',
#   'publisher': 'Colibri Games',
#   'score_rank': '',
#   'positive': 5075,
#   'negative': 723,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 326,
#   'average_2weeks': 0,
#   'median_forever': 315,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 192},
#  '1089350': {'appid': 1089350,
#   'name': 'NBA 2K20',
#   'developer': 'Visual Concepts',
#   'publisher': '2K',
#   'score_rank': '',
#   'positive': 30270,
#   'negative': 29147,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 9188,
#   'average_2weeks': 381,
#   'median_forever': 2367,
#   'median_2weeks': 395,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 4666},
#  '224260': {'appid': 224260,
#   'name': 'No More Room in Hell',
#   'developer': 'No More Room in Hell Team',
#   'publisher': 'Lever Games',
#   'score_rank': '',
#   'positive': 56746,
#   'negative': 6533,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 501,
#   'average_2weeks': 30,
#   'median_forever': 107,
#   'median_2weeks': 49,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 881},
#  '370910': {'appid': 370910,
#   'name': 'Kathy Rain',
#   'developer': 'Clifftop Games',
#   'publisher': 'Raw Fury',
#   'score_rank': '',
#   'positive': 3135,
#   'negative': 255,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1636,
#   'average_2weeks': 246,
#   'median_forever': 270,
#   'median_2weeks': 246,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 5},
#  '219990': {'appid': 219990,
#   'name': 'Grim Dawn',
#   'developer': 'Crate Entertainment',
#   'publisher': 'Crate Entertainment',
#   'score_rank': '',
#   'positive': 65139,
#   'negative': 4624,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2414,
#   'average_2weeks': 164,
#   'median_forever': 1089,
#   'median_2weeks': 164,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 4880},
#  '1046930': {'appid': 1046930,
#   'name': 'Dota Underlords',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 72698,
#   'negative': 15168,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1742,
#   'average_2weeks': 596,
#   'median_forever': 272,
#   'median_2weeks': 1131,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3107},
#  '333930': {'appid': 333930,
#   'name': 'Dirty Bomb',
#   'developer': 'Splash Damage',
#   'publisher': 'Warchest Ltd.',
#   'score_rank': '',
#   'positive': 47167,
#   'negative': 10932,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 675,
#   'average_2weeks': 1,
#   'median_forever': 76,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 178},
#  '239140': {'appid': 239140,
#   'name': 'Dying Light',
#   'developer': 'Techland',
#   'publisher': 'Techland',
#   'score_rank': '',
#   'positive': 267809,
#   'negative': 13932,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2377,
#   'average_2weeks': 244,
#   'median_forever': 1192,
#   'median_2weeks': 209,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 5461},
#  '304050': {'appid': 304050,
#   'name': 'Trove',
#   'developer': 'Trion Worlds',
#   'publisher': 'Trion Worlds',
#   'score_rank': '',
#   'positive': 67708,
#   'negative': 15972,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2730,
#   'average_2weeks': 1512,
#   'median_forever': 187,
#   'median_2weeks': 1501,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2026},
#  '203160': {'appid': 203160,
#   'name': 'Tomb Raider',
#   'developer': 'Crystal Dynamics, Eidos-Montréal, Feral Interactive (Mac), Feral Interactive (Linux), Nixxes',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 196559,
#   'negative': 7754,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 759,
#   'average_2weeks': 94,
#   'median_forever': 460,
#   'median_2weeks': 113,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 1304},
#  '648800': {'appid': 648800,
#   'name': 'Raft',
#   'developer': 'Redbeet Interactive',
#   'publisher': 'Axolot Games',
#   'score_rank': '',
#   'positive': 132531,
#   'negative': 10203,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1333,
#   'average_2weeks': 197,
#   'median_forever': 724,
#   'median_2weeks': 175,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 4901},
#  '632360': {'appid': 632360,
#   'name': 'Risk of Rain 2',
#   'developer': 'Hopoo Games',
#   'publisher': 'Gearbox Publishing',
#   'score_rank': '',
#   'positive': 162333,
#   'negative': 5925,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3087,
#   'average_2weeks': 164,
#   'median_forever': 1434,
#   'median_2weeks': 144,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 6775},
#  '60': {'appid': 60,
#   'name': 'Ricochet',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 3581,
#   'negative': 823,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 34,
#   'average_2weeks': 0,
#   'median_forever': 6,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 4},
#  '255710': {'appid': 255710,
#   'name': 'Cities: Skylines',
#   'developer': 'Colossal Order Ltd.',
#   'publisher': 'Paradox Interactive',
#   'score_rank': '',
#   'positive': 163675,
#   'negative': 11971,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3900,
#   'average_2weeks': 384,
#   'median_forever': 821,
#   'median_2weeks': 78,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 14496},
#  '278360': {'appid': 278360,
#   'name': 'A Story About My Uncle',
#   'developer': 'Gone North Games',
#   'publisher': 'Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 25190,
#   'negative': 2235,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 624,
#   'average_2weeks': 2,
#   'median_forever': 214,
#   'median_2weeks': 2,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 15},
#  '439700': {'appid': 439700,
#   'name': 'Z1 Battle Royale: Test Server',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 1309,
#   'negative': 1167,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 64,
#   'average_2weeks': 0,
#   'median_forever': 19,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '360': {'appid': 360,
#   'name': 'Half-Life Deathmatch: Source',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 2250,
#   'negative': 747,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 674,
#   'average_2weeks': 0,
#   'median_forever': 10,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 8},
#  '588430': {'appid': 588430,
#   'name': 'Fallout Shelter',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 41259,
#   'negative': 5389,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 778,
#   'average_2weeks': 82,
#   'median_forever': 128,
#   'median_2weeks': 82,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1319},
#  '275850': {'appid': 275850,
#   'name': "No Man's Sky",
#   'developer': 'Hello Games',
#   'publisher': 'Hello Games',
#   'score_rank': '',
#   'positive': 157122,
#   'negative': 56842,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2578,
#   'average_2weeks': 249,
#   'median_forever': 1169,
#   'median_2weeks': 114,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 5684},
#  '273110': {'appid': 273110,
#   'name': 'Counter-Strike Nexon: Studio',
#   'developer': 'Valve Corporation, Nexon Korea Corporation',
#   'publisher': 'Nexon Korea Corporation',
#   'score_rank': '',
#   'positive': 25785,
#   'negative': 13257,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 928,
#   'average_2weeks': 652,
#   'median_forever': 65,
#   'median_2weeks': 652,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 465},
#  '365590': {'appid': 365590,
#   'name': 'Tom Clancy’s The Division',
#   'developer': 'Massive Entertainment',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 58310,
#   'negative': 26592,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5218,
#   'average_2weeks': 193,
#   'median_forever': 1711,
#   'median_2weeks': 193,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 1064},
#  '377160': {'appid': 377160,
#   'name': 'Fallout 4',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 208571,
#   'negative': 51910,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5692,
#   'average_2weeks': 930,
#   'median_forever': 1885,
#   'median_2weeks': 470,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 17608},
#  '10180': {'appid': 10180,
#   'name': 'Call of Duty: Modern Warfare 2',
#   'developer': 'Infinity Ward',
#   'publisher': 'Activision',
#   'score_rank': '',
#   'positive': 41141,
#   'negative': 3199,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 898,
#   'average_2weeks': 4,
#   'median_forever': 317,
#   'median_2weeks': 4,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 510},
#  '814380': {'appid': 814380,
#   'name': 'Sekiro: Shadows Die Twice - GOTY Edition',
#   'developer': 'FromSoftware',
#   'publisher': 'Activision (Excluding Japan and Asia), FromSoftware (Japan), 方块游戏 (Asia)',
#   'score_rank': '',
#   'positive': 148657,
#   'negative': 7994,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2267,
#   'average_2weeks': 356,
#   'median_forever': 1435,
#   'median_2weeks': 366,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 5844},
#  '466240': {'appid': 466240,
#   'name': 'Deceit',
#   'developer': 'World Makers',
#   'publisher': 'World Makers',
#   'score_rank': '',
#   'positive': 60787,
#   'negative': 16335,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 432,
#   'average_2weeks': 9,
#   'median_forever': 95,
#   'median_2weeks': 15,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 638},
#  '40': {'appid': 40,
#   'name': 'Deathmatch Classic',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1790,
#   'negative': 401,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 124,
#   'average_2weeks': 0,
#   'median_forever': 10,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 5},
#  '107410': {'appid': 107410,
#   'name': 'Arma 3',
#   'developer': 'Bohemia Interactive',
#   'publisher': 'Bohemia Interactive',
#   'score_rank': '',
#   'positive': 187075,
#   'negative': 19868,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 11606,
#   'average_2weeks': 770,
#   'median_forever': 1525,
#   'median_2weeks': 340,
#   'price': '749',
#   'initialprice': '2999',
#   'discount': '75',
#   'ccu': 12816},
#  '844870': {'appid': 844870,
#   'name': 'KurtzPel',
#   'developer': 'KOG',
#   'publisher': 'KOG',
#   'score_rank': '',
#   'positive': 21210,
#   'negative': 12429,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 440,
#   'average_2weeks': 0,
#   'median_forever': 87,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 336},
#  '30': {'appid': 30,
#   'name': 'Day of Defeat',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 4870,
#   'negative': 543,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 546,
#   'average_2weeks': 0,
#   'median_forever': 13,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 131},
#  '363970': {'appid': 363970,
#   'name': 'Clicker Heroes',
#   'developer': 'Playsaurus',
#   'publisher': 'Playsaurus',
#   'score_rank': '',
#   'positive': 50486,
#   'negative': 5613,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 6726,
#   'average_2weeks': 0,
#   'median_forever': 577,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3446},
#  '289070': {'appid': 289070,
#   'name': 'Sid Meier’s Civilization VI',
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 156807,
#   'negative': 32348,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 4320,
#   'average_2weeks': 525,
#   'median_forever': 1356,
#   'median_2weeks': 337,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 33660},
#  '813820': {'appid': 813820,
#   'name': 'Realm Royale',
#   'developer': 'Heroic Leap Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 37254,
#   'negative': 12627,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 720,
#   'average_2weeks': 123,
#   'median_forever': 119,
#   'median_2weeks': 234,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 966},
#  '374320': {'appid': 374320,
#   'name': 'DARK SOULS III',
#   'developer': 'FromSoftware, Inc.',
#   'publisher': 'FromSoftware, Inc., BANDAI NAMCO Entertainment',
#   'score_rank': '',
#   'positive': 274071,
#   'negative': 17072,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5042,
#   'average_2weeks': 214,
#   'median_forever': 1908,
#   'median_2weeks': 156,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 14571},
#  '44350': {'appid': 44350,
#   'name': 'GRID 2',
#   'developer': 'Codemasters Racing',
#   'publisher': 'Codemasters',
#   'score_rank': '',
#   'positive': 23277,
#   'negative': 4567,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 453,
#   'average_2weeks': 143,
#   'median_forever': 156,
#   'median_2weeks': 143,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 148}}

# %%
import steamspypi

data_request = dict()
data_request['request'] = 'genre'
data_request['genre'] = 'Multiplayer'

data = steamspypi.download(data_request)
data
# Out:
# {'578080': {'appid': 578080,
#   'name': 'PUBG: BATTLEGROUNDS',
#   'developer': 'KRAFTON, Inc.',
#   'publisher': 'KRAFTON, Inc.',
#   'score_rank': '',
#   'positive': 1020533,
#   'negative': 834227,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 24119,
#   'average_2weeks': 455,
#   'median_forever': 10045,
#   'median_2weeks': 166,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 286942},
#  '252490': {'appid': 252490,
#   'name': 'Rust',
#   'developer': 'Facepunch Studios',
#   'publisher': 'Facepunch Studios',
#   'score_rank': '',
#   'positive': 605718,
#   'negative': 92525,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 19351,
#   'average_2weeks': 1028,
#   'median_forever': 3117,
#   'median_2weeks': 640,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 73507},
#  '1063730': {'appid': 1063730,
#   'name': 'New World',
#   'developer': 'Amazon Games',
#   'publisher': 'Amazon Games',
#   'score_rank': '',
#   'positive': 127666,
#   'negative': 45268,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5421,
#   'average_2weeks': 1717,
#   'median_forever': 3404,
#   'median_2weeks': 802,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 159838},
#  '236390': {'appid': 236390,
#   'name': 'War Thunder',
#   'developer': 'Gaijin Entertainment',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 204398,
#   'negative': 54002,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5576,
#   'average_2weeks': 1206,
#   'median_forever': 438,
#   'median_2weeks': 638,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31163},
#  '238960': {'appid': 238960,
#   'name': 'Path of Exile',
#   'developer': 'Grinding Gear Games',
#   'publisher': 'Grinding Gear Games',
#   'score_rank': '',
#   'positive': 157410,
#   'negative': 15981,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5977,
#   'average_2weeks': 1920,
#   'median_forever': 464,
#   'median_2weeks': 2275,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 46035},
#  '1097150': {'appid': 1097150,
#   'name': 'Fall Guys: Ultimate Knockout',
#   'developer': 'Mediatonic',
#   'publisher': '',
#   'score_rank': '',
#   'positive': 330623,
#   'negative': 66978,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 956,
#   'average_2weeks': 73,
#   'median_forever': 465,
#   'median_2weeks': 31,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 5240},
#  '227940': {'appid': 227940,
#   'name': 'Heroes & Generals',
#   'developer': 'RETO MOTO',
#   'publisher': 'RETO MOTO',
#   'score_rank': '',
#   'positive': 91549,
#   'negative': 43619,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 974,
#   'average_2weeks': 276,
#   'median_forever': 87,
#   'median_2weeks': 330,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2214},
#  '291480': {'appid': 291480,
#   'name': 'Warface',
#   'developer': 'MY.GAMES',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 49547,
#   'negative': 23104,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 615,
#   'average_2weeks': 94,
#   'median_forever': 111,
#   'median_2weeks': 148,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2621},
#  '552990': {'appid': 552990,
#   'name': 'World of Warships',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 72446,
#   'negative': 18099,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1775,
#   'average_2weeks': 421,
#   'median_forever': 181,
#   'median_2weeks': 788,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9887},
#  '301520': {'appid': 301520,
#   'name': 'Robocraft',
#   'developer': 'Freejam',
#   'publisher': 'Freejam',
#   'score_rank': '',
#   'positive': 85926,
#   'negative': 32316,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1299,
#   'average_2weeks': 239,
#   'median_forever': 184,
#   'median_2weeks': 273,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 291},
#  '755790': {'appid': 755790,
#   'name': 'Ring of Elysium',
#   'developer': 'Aurora Studio',
#   'publisher': 'TCH Scarlet Limited',
#   'score_rank': '',
#   'positive': 73617,
#   'negative': 25217,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 662,
#   'average_2weeks': 21,
#   'median_forever': 109,
#   'median_2weeks': 28,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1380},
#  '433850': {'appid': 433850,
#   'name': 'Z1 Battle Royale',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 115763,
#   'negative': 93225,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2273,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 101},
#  '346110': {'appid': 346110,
#   'name': 'ARK: Survival Evolved',
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'publisher': 'Studio Wildcard',
#   'score_rank': '',
#   'positive': 383425,
#   'negative': 90947,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 11724,
#   'average_2weeks': 1494,
#   'median_forever': 1663,
#   'median_2weeks': 1028,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 42817},
#  '417910': {'appid': 417910,
#   'name': 'Street Warriors Online',
#   'developer': 'Crazy Rocks Studios',
#   'publisher': 'Crazy Rocks Studios',
#   'score_rank': '',
#   'positive': 973,
#   'negative': 710,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 61,
#   'average_2weeks': 0,
#   'median_forever': 52,
#   'median_2weeks': 0,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 0},
#  '218230': {'appid': 218230,
#   'name': 'PlanetSide 2',
#   'developer': 'Rogue Planet Games',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 52096,
#   'negative': 11413,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1665,
#   'average_2weeks': 572,
#   'median_forever': 157,
#   'median_2weeks': 848,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1520},
#  '444200': {'appid': 444200,
#   'name': 'World of Tanks Blitz',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 74412,
#   'negative': 18438,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2659,
#   'average_2weeks': 1174,
#   'median_forever': 151,
#   'median_2weeks': 1640,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 31091},
#  '304050': {'appid': 304050,
#   'name': 'Trove',
#   'developer': 'Trion Worlds',
#   'publisher': 'Trion Worlds',
#   'score_rank': '',
#   'positive': 67708,
#   'negative': 15972,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2730,
#   'average_2weeks': 1512,
#   'median_forever': 187,
#   'median_2weeks': 1501,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2026},
#  '439700': {'appid': 439700,
#   'name': 'Z1 Battle Royale: Test Server',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 1309,
#   'negative': 1167,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 64,
#   'average_2weeks': 0,
#   'median_forever': 19,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '273110': {'appid': 273110,
#   'name': 'Counter-Strike Nexon: Studio',
#   'developer': 'Valve Corporation, Nexon Korea Corporation',
#   'publisher': 'Nexon Korea Corporation',
#   'score_rank': '',
#   'positive': 25785,
#   'negative': 13257,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 928,
#   'average_2weeks': 652,
#   'median_forever': 65,
#   'median_2weeks': 652,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 465},
#  '109600': {'appid': 109600,
#   'name': 'Neverwinter',
#   'developer': 'Cryptic Studios',
#   'publisher': 'Perfect World Entertainment',
#   'score_rank': '',
#   'positive': 25904,
#   'negative': 7355,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1251,
#   'average_2weeks': 517,
#   'median_forever': 344,
#   'median_2weeks': 517,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1743},
#  '221100': {'appid': 221100,
#   'name': 'DayZ',
#   'developer': 'Bohemia Interactive',
#   'publisher': 'Bohemia Interactive',
#   'score_rank': '',
#   'positive': 193707,
#   'negative': 87878,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 8846,
#   'average_2weeks': 878,
#   'median_forever': 2561,
#   'median_2weeks': 916,
#   'price': '4499',
#   'initialprice': '4499',
#   'discount': '0',
#   'ccu': 31559},
#  '555570': {'appid': 555570,
#   'name': 'Infestation: The New Z',
#   'developer': 'Fredaikis AB',
#   'publisher': 'OP Productions LLC',
#   'score_rank': '',
#   'positive': 17231,
#   'negative': 15408,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 512,
#   'average_2weeks': 1,
#   'median_forever': 51,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 414},
#  '113400': {'appid': 113400,
#   'name': 'APB Reloaded',
#   'developer': 'Reloaded Productions',
#   'publisher': 'Little Orbit',
#   'score_rank': '',
#   'positive': 22617,
#   'negative': 12863,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 6283,
#   'average_2weeks': 28,
#   'median_forever': 155,
#   'median_2weeks': 28,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 312},
#  '407530': {'appid': 407530,
#   'name': 'ARK: Survival Of The Fittest',
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'publisher': 'Studio Wildcard',
#   'score_rank': '',
#   'positive': 5855,
#   'negative': 3518,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 126,
#   'average_2weeks': 0,
#   'median_forever': 25,
#   'median_2weeks': 0,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 13},
#  '339610': {'appid': 339610,
#   'name': 'Freestyle 2: Street Basketball',
#   'developer': 'JOYCITY',
#   'publisher': 'JOYCITY',
#   'score_rank': '',
#   'positive': 8258,
#   'negative': 3031,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2407,
#   'average_2weeks': 0,
#   'median_forever': 90,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 459},
#  '1203220': {'appid': 1203220,
#   'name': 'NARAKA: BLADEPOINT',
#   'developer': '24 Entertainment',
#   'publisher': 'NetEase Games Montréal',
#   'score_rank': '',
#   'positive': 51196,
#   'negative': 13500,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 4329,
#   'average_2weeks': 853,
#   'median_forever': 2274,
#   'median_2weeks': 588,
#   'price': '1399',
#   'initialprice': '1999',
#   'discount': '30',
#   'ccu': 133846},
#  '1286830': {'appid': 1286830,
#   'name': 'STAR WARS: The Old Republic',
#   'developer': 'BioWare',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 30334,
#   'negative': 3042,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1428,
#   'average_2weeks': 577,
#   'median_forever': 268,
#   'median_2weeks': 607,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 6650},
#  '280790': {'appid': 280790,
#   'name': 'Creativerse',
#   'developer': 'Playful Corp.',
#   'publisher': 'Throwback Entertainment, Playful Corp.',
#   'score_rank': '',
#   'positive': 23713,
#   'negative': 5685,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1036,
#   'average_2weeks': 0,
#   'median_forever': 111,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 213},
#  '397900': {'appid': 397900,
#   'name': 'Business Tour - Board Game with Online Multiplayer',
#   'developer': 'Creobit',
#   'publisher': '8Floor',
#   'score_rank': '',
#   'positive': 33498,
#   'negative': 21586,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 577,
#   'average_2weeks': 98,
#   'median_forever': 229,
#   'median_2weeks': 150,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1198},
#  '306130': {'appid': 306130,
#   'name': 'The Elder Scrolls Online',
#   'developer': 'Zenimax Online Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 89529,
#   'negative': 19963,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 6959,
#   'average_2weeks': 1182,
#   'median_forever': 1624,
#   'median_2weeks': 1469,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 18218},
#  '355840': {'appid': 355840,
#   'name': 'Survarium',
#   'developer': 'Vostok Games',
#   'publisher': 'Vostok Games',
#   'score_rank': '',
#   'positive': 13417,
#   'negative': 11303,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 495,
#   'average_2weeks': 6,
#   'median_forever': 47,
#   'median_2weeks': 11,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 403},
#  '438100': {'appid': 438100,
#   'name': 'VRChat',
#   'developer': 'VRChat Inc.',
#   'publisher': 'VRChat Inc.',
#   'score_rank': '',
#   'positive': 101448,
#   'negative': 10434,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1108,
#   'average_2weeks': 455,
#   'median_forever': 94,
#   'median_2weeks': 280,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 18558},
#  '506540': {'appid': 506540,
#   'name': 'Last Man Standing',
#   'developer': 'Free Reign Entertainment, Free Reign Entertainment',
#   'publisher': 'Free Reign Entertainment',
#   'score_rank': '',
#   'positive': 11322,
#   'negative': 7204,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 489,
#   'average_2weeks': 0,
#   'median_forever': 93,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '884660': {'appid': 884660,
#   'name': 'CRSED: F.O.A.D.',
#   'developer': 'Darkflow Software',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 28634,
#   'negative': 6911,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 244,
#   'average_2weeks': 71,
#   'median_forever': 49,
#   'median_2weeks': 85,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 575},
#  '386180': {'appid': 386180,
#   'name': 'Crossout',
#   'developer': 'Targem Games',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 35486,
#   'negative': 10555,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1128,
#   'average_2weeks': 523,
#   'median_forever': 148,
#   'median_2weeks': 523,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3796},
#  '35450': {'appid': 35450,
#   'name': 'Red Orchestra 2: Heroes of Stalingrad with Rising Storm',
#   'developer': 'Tripwire Interactive',
#   'publisher': 'Tripwire Interactive',
#   'score_rank': '',
#   'positive': 32418,
#   'negative': 2657,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2515,
#   'average_2weeks': 26,
#   'median_forever': 270,
#   'median_2weeks': 26,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 315},
#  '212500': {'appid': 212500,
#   'name': 'The Lord of the Rings Online',
#   'developer': 'Standing Stone Games, LLC',
#   'publisher': 'Standing Stone Games, LLC',
#   'score_rank': '',
#   'positive': 11439,
#   'negative': 2664,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2344,
#   'average_2weeks': 1227,
#   'median_forever': 179,
#   'median_2weeks': 1227,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1384},
#  '8500': {'appid': 8500,
#   'name': 'EVE Online',
#   'developer': 'CCP',
#   'publisher': 'CCP',
#   'score_rank': '',
#   'positive': 18991,
#   'negative': 6127,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 4503,
#   'average_2weeks': 1,
#   'median_forever': 170,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3707},
#  '200210': {'appid': 200210,
#   'name': 'Realm of the Mad God Exalt',
#   'developer': 'Wild Shadow Studios, Deca Games',
#   'publisher': 'Deca Games',
#   'score_rank': '',
#   'positive': 33870,
#   'negative': 6243,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 3653,
#   'average_2weeks': 190,
#   'median_forever': 127,
#   'median_2weeks': 263,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1314},
#  '299360': {'appid': 299360,
#   'name': 'Block N Load',
#   'developer': 'Toadman Interactive, Artplant',
#   'publisher': 'Toadman Interactive',
#   'score_rank': '',
#   'positive': 12078,
#   'negative': 3348,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 420,
#   'average_2weeks': 1,
#   'median_forever': 76,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 39},
#  '744900': {'appid': 744900,
#   'name': 'Dead Frontier 2',
#   'developer': 'Creaky Corpse Ltd',
#   'publisher': 'Creaky Corpse Ltd',
#   'score_rank': '',
#   'positive': 13307,
#   'negative': 5398,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 240,
#   'average_2weeks': 0,
#   'median_forever': 52,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 697},
#  '224600': {'appid': 224600,
#   'name': 'Defiance',
#   'developer': 'Trion Worlds',
#   'publisher': 'Trion Worlds',
#   'score_rank': '',
#   'positive': 9675,
#   'negative': 3000,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 673,
#   'average_2weeks': 0,
#   'median_forever': 164,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2},
#  '99900': {'appid': 99900,
#   'name': 'Spiral Knights',
#   'developer': 'Grey Havens, LLC',
#   'publisher': 'Grey Havens, LLC',
#   'score_rank': '',
#   'positive': 18505,
#   'negative': 3532,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1789,
#   'average_2weeks': 3,
#   'median_forever': 84,
#   'median_2weeks': 5,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 153},
#  '39210': {'appid': 39210,
#   'name': 'FINAL FANTASY XIV Online',
#   'developer': 'Square Enix',
#   'publisher': 'Square Enix',
#   'score_rank': '',
#   'positive': 41447,
#   'negative': 5122,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 17142,
#   'average_2weeks': 675,
#   'median_forever': 5686,
#   'median_2weeks': 864,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 31181},
#  '380600': {'appid': 380600,
#   'name': 'Fishing Planet',
#   'developer': 'Fishing Planet LLC',
#   'publisher': 'Fishing Planet LLC',
#   'score_rank': '',
#   'positive': 26169,
#   'negative': 5136,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 784,
#   'average_2weeks': 11,
#   'median_forever': 48,
#   'median_2weeks': 20,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2348},
#  '335240': {'appid': 335240,
#   'name': 'Transformice',
#   'developer': 'Atelier 801',
#   'publisher': 'Atelier 801',
#   'score_rank': '',
#   'positive': 18195,
#   'negative': 2772,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1116,
#   'average_2weeks': 2,
#   'median_forever': 79,
#   'median_2weeks': 4,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1972},
#  '440900': {'appid': 440900,
#   'name': 'Conan Exiles',
#   'developer': 'Funcom',
#   'publisher': 'Funcom',
#   'score_rank': '',
#   'positive': 57540,
#   'negative': 15632,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 5249,
#   'average_2weeks': 1499,
#   'median_forever': 1200,
#   'median_2weeks': 1722,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 8175},
#  '905370': {'appid': 905370,
#   'name': "Conqueror's Blade",
#   'developer': 'Booming Tech',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 16576,
#   'negative': 5491,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1967,
#   'average_2weeks': 2,
#   'median_forever': 403,
#   'median_2weeks': 2,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 3594},
#  '513710': {'appid': 513710,
#   'name': 'SCUM',
#   'developer': 'Gamepires',
#   'publisher': 'Gamepires',
#   'score_rank': '',
#   'positive': 46523,
#   'negative': 16706,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2624,
#   'average_2weeks': 577,
#   'median_forever': 650,
#   'median_2weeks': 638,
#   'price': '3499',
#   'initialprice': '3499',
#   'discount': '0',
#   'ccu': 10806},
#  '582660': {'appid': 582660,
#   'name': 'Black Desert',
#   'developer': 'Pearl Abyss',
#   'publisher': 'Pearl Abyss',
#   'score_rank': '',
#   'positive': 37298,
#   'negative': 12216,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 5157,
#   'average_2weeks': 1172,
#   'median_forever': 312,
#   'median_2weeks': 2222,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 17299},
#  '359320': {'appid': 359320,
#   'name': 'Elite Dangerous',
#   'developer': 'Frontier Developments',
#   'publisher': 'Frontier Developments',
#   'score_rank': '',
#   'positive': 59294,
#   'negative': 17281,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 7451,
#   'average_2weeks': 1039,
#   'median_forever': 1896,
#   'median_2weeks': 2071,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 4598},
#  '39120': {'appid': 39120,
#   'name': 'RIFT',
#   'developer': 'gamigo US Inc.',
#   'publisher': 'gamigo US Inc.',
#   'score_rank': '',
#   'positive': 7720,
#   'negative': 2585,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1678,
#   'average_2weeks': 0,
#   'median_forever': 180,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 231},
#  '24200': {'appid': 24200,
#   'name': 'DC Universe Online',
#   'developer': 'Dimensional Ink Games',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 13856,
#   'negative': 3512,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 3429,
#   'average_2weeks': 97,
#   'median_forever': 479,
#   'median_2weeks': 97,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 563},
#  '372000': {'appid': 372000,
#   'name': 'Tree of Savior (English Ver.)',
#   'developer': 'IMCGAMES Co.,Ltd.',
#   'publisher': 'IMCGAMES Co.,Ltd.',
#   'score_rank': '',
#   'positive': 12497,
#   'negative': 6854,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1007,
#   'average_2weeks': 0,
#   'median_forever': 290,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 887},
#  '766570': {'appid': 766570,
#   'name': 'Russian Fishing 4',
#   'developer': 'Russian Fishing',
#   'publisher': 'Russian Fishing',
#   'score_rank': '',
#   'positive': 15046,
#   'negative': 4995,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1022,
#   'average_2weeks': 55,
#   'median_forever': 59,
#   'median_2weeks': 55,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 6142},
#  '295110': {'appid': 295110,
#   'name': 'Just Survive',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 46896,
#   'negative': 32624,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 4916,
#   'average_2weeks': 0,
#   'median_forever': 1265,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2},
#  '550900': {'appid': 550900,
#   'name': 'Metin2',
#   'developer': 'WEBZEN Inc.',
#   'publisher': 'Gameforge 4D GmbH',
#   'score_rank': '',
#   'positive': 9512,
#   'negative': 4093,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 917,
#   'average_2weeks': 13,
#   'median_forever': 148,
#   'median_2weeks': 13,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 699},
#  '630100': {'appid': 630100,
#   'name': 'SoulWorker - Anime Action MMO',
#   'developer': 'Lion Games Co., Ltd.',
#   'publisher': 'Gameforge 4D GmbH',
#   'score_rank': '',
#   'positive': 11726,
#   'negative': 2999,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 406,
#   'average_2weeks': 0,
#   'median_forever': 145,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4},
#  '212070': {'appid': 212070,
#   'name': 'Star Conflict',
#   'developer': 'Star Gem Inc.',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 10257,
#   'negative': 3396,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 3025,
#   'average_2weeks': 0,
#   'median_forever': 77,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 224},
#  '9900': {'appid': 9900,
#   'name': 'Star Trek Online',
#   'developer': 'Cryptic Studios',
#   'publisher': 'Perfect World Entertainment',
#   'score_rank': '',
#   'positive': 12116,
#   'negative': 3308,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2649,
#   'average_2weeks': 140,
#   'median_forever': 410,
#   'median_2weeks': 168,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1885},
#  '268420': {'appid': 268420,
#   'name': 'Aura Kingdom',
#   'developer': 'X-Legend',
#   'publisher': 'Aeria Games',
#   'score_rank': '',
#   'positive': 6762,
#   'negative': 1804,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 951,
#   'average_2weeks': 0,
#   'median_forever': 92,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 102},
#  '646910': {'appid': 646910,
#   'name': 'The Crew 2',
#   'developer': 'Ivory Tower',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 42621,
#   'negative': 10588,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 2836,
#   'average_2weeks': 152,
#   'median_forever': 1947,
#   'median_2weeks': 228,
#   'price': '4999',
#   'initialprice': '4999',
#   'discount': '0',
#   'ccu': 1264},
#  '436520': {'appid': 436520,
#   'name': 'Line of Sight',
#   'developer': 'BlackSpot Entertainment',
#   'publisher': 'BlackSpot Entertainment',
#   'score_rank': '',
#   'positive': 5246,
#   'negative': 3687,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 327,
#   'average_2weeks': 55,
#   'median_forever': 56,
#   'median_2weeks': 55,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 58},
#  '1254120': {'appid': 1254120,
#   'name': 'Bless Unleashed',
#   'developer': 'Round8 Studio',
#   'publisher': 'NEOWIZ',
#   'score_rank': '',
#   'positive': 13721,
#   'negative': 13175,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 1096,
#   'average_2weeks': 849,
#   'median_forever': 121,
#   'median_2weeks': 849,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 7866},
#  '1180380': {'appid': 1180380,
#   'name': 'Stay Out',
#   'developer': 'Mobile Technologies LLC',
#   'publisher': 'Mobile Technologies LLC',
#   'score_rank': '',
#   'positive': 5490,
#   'negative': 5381,
#   'userscore': 0,
#   'owners': '2,000,000 .. 5,000,000',
#   'average_forever': 92,
#   'average_2weeks': 24,
#   'median_forever': 33,
#   'median_2weeks': 24,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1838},
#  '389430': {'appid': 389430,
#   'name': 'Knight Online',
#   'developer': 'Noah System, Mgame',
#   'publisher': 'NTTGame',
#   'score_rank': '',
#   'positive': 4754,
#   'negative': 4931,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2970,
#   'average_2weeks': 0,
#   'median_forever': 22,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1623},
#  '761890': {'appid': 761890,
#   'name': 'Albion Online',
#   'developer': 'Sandbox Interactive GmbH',
#   'publisher': 'Sandbox Interactive GmbH',
#   'score_rank': '',
#   'positive': 32928,
#   'negative': 8482,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2360,
#   'average_2weeks': 2566,
#   'median_forever': 245,
#   'median_2weeks': 2768,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 6448},
#  '1056640': {'appid': 1056640,
#   'name': 'Phantasy Star Online 2',
#   'developer': 'SEGA',
#   'publisher': 'SEGA',
#   'score_rank': '',
#   'positive': 12994,
#   'negative': 4831,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2836,
#   'average_2weeks': 94,
#   'median_forever': 272,
#   'median_2weeks': 123,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2311},
#  '349700': {'appid': 349700,
#   'name': "Romero's Aftermath",
#   'developer': 'Free Reign Entertainment',
#   'publisher': 'OP Productions LLC, Free Reign East LLC',
#   'score_rank': '',
#   'positive': 5561,
#   'negative': 5875,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 204,
#   'average_2weeks': 0,
#   'median_forever': 59,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '442080': {'appid': 442080,
#   'name': 'Riders of Icarus',
#   'developer': 'WeMade',
#   'publisher': 'VALOFE',
#   'score_rank': '',
#   'positive': 6732,
#   'negative': 3379,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2824,
#   'average_2weeks': 0,
#   'median_forever': 118,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 185},
#  '113420': {'appid': 113420,
#   'name': 'Fallen Earth Free2Play',
#   'developer': 'Little Orbit',
#   'publisher': 'Little Orbit',
#   'score_rank': '',
#   'positive': 4020,
#   'negative': 3062,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 195,
#   'average_2weeks': 1,
#   'median_forever': 30,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 166},
#  '578310': {'appid': 578310,
#   'name': 'BRAIN / OUT',
#   'developer': 'Desertkun',
#   'publisher': 'Desertkun',
#   'score_rank': '',
#   'positive': 12092,
#   'negative': 2556,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 677,
#   'average_2weeks': 18,
#   'median_forever': 42,
#   'median_2weeks': 18,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 157},
#  '269210': {'appid': 269210,
#   'name': 'Hero Siege',
#   'developer': 'Elias Viglione, Jussi Kukkonen',
#   'publisher': 'Panic Art Studios',
#   'score_rank': '',
#   'positive': 22068,
#   'negative': 6851,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 690,
#   'average_2weeks': 0,
#   'median_forever': 229,
#   'median_2weeks': 0,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 1004},
#  '809960': {'appid': 809960,
#   'name': 'Radical Heights',
#   'developer': 'Boss Key Productions',
#   'publisher': 'Boss Key Productions',
#   'score_rank': '',
#   'positive': 6104,
#   'negative': 3948,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 119,
#   'average_2weeks': 0,
#   'median_forever': 41,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '342200': {'appid': 342200,
#   'name': 'MechWarrior Online Solaris 7',
#   'developer': 'Piranha Games Inc.',
#   'publisher': 'Piranha Games Inc.',
#   'score_rank': '',
#   'positive': 7035,
#   'negative': 1971,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2055,
#   'average_2weeks': 0,
#   'median_forever': 142,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 844},
#  '242860': {'appid': 242860,
#   'name': 'Verdun',
#   'developer': 'M2H, Blackmill Games',
#   'publisher': 'M2H',
#   'score_rank': '',
#   'positive': 29838,
#   'negative': 5025,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 603,
#   'average_2weeks': 37,
#   'median_forever': 221,
#   'median_2weeks': 37,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 175},
#  '537180': {'appid': 537180,
#   'name': 'Digimon Masters Online',
#   'developer': 'Move Games Co., Ltd.',
#   'publisher': 'MOVE ON USA CO.',
#   'score_rank': '',
#   'positive': 5103,
#   'negative': 2418,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 866,
#   'average_2weeks': 0,
#   'median_forever': 63,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1057},
#  '215080': {'appid': 215080,
#   'name': 'WAKFU',
#   'developer': 'Ankama Studio',
#   'publisher': 'Ankama Games',
#   'score_rank': '',
#   'positive': 6329,
#   'negative': 2015,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 6218,
#   'average_2weeks': 1,
#   'median_forever': 260,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 408},
#  '686810': {'appid': 686810,
#   'name': 'Hell Let Loose',
#   'developer': 'Black Matter Pty Ltd',
#   'publisher': 'Team17',
#   'score_rank': '',
#   'positive': 45524,
#   'negative': 9238,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 1930,
#   'average_2weeks': 225,
#   'median_forever': 1042,
#   'median_2weeks': 233,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 4157},
#  '1238840': {'appid': 1238840,
#   'name': 'Battlefield 1 ',
#   'developer': 'DICE',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 51909,
#   'negative': 9226,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 1610,
#   'average_2weeks': 238,
#   'median_forever': 598,
#   'median_2weeks': 229,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 7314},
#  '438040': {'appid': 438040,
#   'name': 'Shakes and Fidget',
#   'developer': 'Playa Games GmbH',
#   'publisher': 'Playa Games GmbH',
#   'score_rank': '',
#   'positive': 21178,
#   'negative': 1569,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2831,
#   'average_2weeks': 169,
#   'median_forever': 203,
#   'median_2weeks': 169,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2831},
#  '240320': {'appid': 240320,
#   'name': 'Panzar',
#   'developer': 'Panzar Studio',
#   'publisher': 'OVALIS INVESTMENTS LIMITED',
#   'score_rank': '',
#   'positive': 3263,
#   'negative': 1738,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 391,
#   'average_2weeks': 0,
#   'median_forever': 162,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 27},
#  '332070': {'appid': 332070,
#   'name': 'School of Dragons',
#   'developer': 'JumpStart Games, Inc.',
#   'publisher': 'JumpStart Games, Inc.',
#   'score_rank': '',
#   'positive': 2609,
#   'negative': 2020,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 306,
#   'average_2weeks': 0,
#   'median_forever': 99,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 62},
#  '893520': {'appid': 893520,
#   'name': 'Creative Destruction',
#   'developer': 'NetEase Games',
#   'publisher': 'NetEase Games',
#   'score_rank': '',
#   'positive': 14119,
#   'negative': 3830,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 776,
#   'average_2weeks': 0,
#   'median_forever': 155,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 189},
#  '696370': {'appid': 696370,
#   'name': 'BROKE PROTOCOL: Online City RPG',
#   'developer': 'Cylinder Studios',
#   'publisher': 'Cylinder Studios',
#   'score_rank': '',
#   'positive': 1982,
#   'negative': 703,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 337,
#   'average_2weeks': 427,
#   'median_forever': 420,
#   'median_2weeks': 427,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 27},
#  '231060': {'appid': 231060,
#   'name': 'Ragnarok Online 2',
#   'developer': 'Gravity, Inc.',
#   'publisher': 'Gravity Interactive',
#   'score_rank': '',
#   'positive': 1778,
#   'negative': 1233,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 498,
#   'average_2weeks': 0,
#   'median_forever': 180,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 6},
#  '814480': {'appid': 814480,
#   'name': 'Mini World: Block Art',
#   'developer': 'Miniwan Technology Co.,Limited',
#   'publisher': 'Miniwan Technology Co.,Limited',
#   'score_rank': '',
#   'positive': 1612,
#   'negative': 1515,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 5292,
#   'average_2weeks': 0,
#   'median_forever': 10388,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 247},
#  '206480': {'appid': 206480,
#   'name': 'Dungeons & Dragons Online',
#   'developer': 'Standing Stone Games, LLC',
#   'publisher': 'Standing Stone Games, LLC',
#   'score_rank': '',
#   'positive': 3548,
#   'negative': 1506,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 584,
#   'average_2weeks': 0,
#   'median_forever': 204,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 249},
#  '226700': {'appid': 226700,
#   'name': 'Infestation: Survivor Stories 2020',
#   'developer': 'Fredaikis AB',
#   'publisher': 'OP Productions LLC',
#   'score_rank': '',
#   'positive': 10696,
#   'negative': 14902,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 1999,
#   'average_2weeks': 0,
#   'median_forever': 553,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 29},
#  '216150': {'appid': 216150,
#   'name': 'MapleStory',
#   'developer': 'Nexon',
#   'publisher': 'Nexon America Inc.',
#   'score_rank': '',
#   'positive': 5933,
#   'negative': 2595,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2656,
#   'average_2weeks': 85,
#   'median_forever': 155,
#   'median_2weeks': 85,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2979},
#  '834910': {'appid': 834910,
#   'name': 'ATLAS',
#   'developer': 'Grapeshot Games, Instinct Games',
#   'publisher': 'Grapeshot Games',
#   'score_rank': '',
#   'positive': 18312,
#   'negative': 20840,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 7099,
#   'average_2weeks': 20,
#   'median_forever': 4791,
#   'median_2weeks': 20,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 2038},
#  '1343370': {'appid': 1343370,
#   'name': 'Old School RuneScape',
#   'developer': 'Jagex Ltd',
#   'publisher': 'Jagex Ltd',
#   'score_rank': '',
#   'positive': 7381,
#   'negative': 867,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2891,
#   'average_2weeks': 1286,
#   'median_forever': 67,
#   'median_2weeks': 1286,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1469},
#  '215280': {'appid': 215280,
#   'name': 'Secret World Legends',
#   'developer': 'Funcom',
#   'publisher': 'Funcom',
#   'score_rank': '',
#   'positive': 5528,
#   'negative': 2698,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 647,
#   'average_2weeks': 0,
#   'median_forever': 159,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 97},
#  '304030': {'appid': 304030,
#   'name': 'ArcheAge',
#   'developer': 'XLGAMES',
#   'publisher': 'Trion Worlds',
#   'score_rank': '',
#   'positive': 3630,
#   'negative': 3337,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2889,
#   'average_2weeks': 0,
#   'median_forever': 379,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 55},
#  '212740': {'appid': 212740,
#   'name': 'TERA - Action MMORPG',
#   'developer': 'Bluehole, Inc.',
#   'publisher': 'Gameforge 4D GmbH',
#   'score_rank': '',
#   'positive': 5215,
#   'negative': 1519,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 4202,
#   'average_2weeks': 0,
#   'median_forever': 201,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 494},
#  '1343400': {'appid': 1343400,
#   'name': 'RuneScape ',
#   'developer': 'Jagex Ltd',
#   'publisher': 'Jagex Ltd',
#   'score_rank': '',
#   'positive': 13769,
#   'negative': 1780,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 200,
#   'average_2weeks': 0,
#   'median_forever': 14,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4737},
#  '418460': {'appid': 418460,
#   'name': 'Rising Storm 2: Vietnam',
#   'developer': 'Antimatter Games, Tripwire Interactive',
#   'publisher': 'Tripwire Interactive',
#   'score_rank': '',
#   'positive': 40571,
#   'negative': 6823,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 2700,
#   'average_2weeks': 179,
#   'median_forever': 623,
#   'median_2weeks': 179,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 667},
#  '376210': {'appid': 376210,
#   'name': 'The Isle',
#   'developer': 'Afterthought LLC',
#   'publisher': 'Afterthought LLC',
#   'score_rank': '',
#   'positive': 36947,
#   'negative': 7694,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 9611,
#   'average_2weeks': 748,
#   'median_forever': 1954,
#   'median_2weeks': 1207,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 3099},
#  '1407200': {'appid': 1407200,
#   'name': 'World of Tanks',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 8744,
#   'negative': 3959,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 155,
#   'average_2weeks': 26,
#   'median_forever': 88,
#   'median_2weeks': 26,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2329},
#  '921060': {'appid': 921060,
#   'name': 'Modern Combat 5',
#   'developer': 'Gameloft',
#   'publisher': 'Gameloft',
#   'score_rank': '',
#   'positive': 2679,
#   'negative': 2306,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 119,
#   'average_2weeks': 0,
#   'median_forever': 39,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 113},
#  '567630': {'appid': 567630,
#   'name': 'Blood of Steel',
#   'developer': 'YC Games',
#   'publisher': 'YC Games',
#   'score_rank': '',
#   'positive': 4182,
#   'negative': 1177,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 926,
#   'average_2weeks': 157,
#   'median_forever': 71,
#   'median_2weeks': 157,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 542},
#  '293540': {'appid': 293540,
#   'name': 'Guns and Robots',
#   'developer': 'Masthead Studios Ltd',
#   'publisher': 'Masthead Studios Ltd, Thegamewallstudios, Gamigo AG',
#   'score_rank': '',
#   'positive': 1134,
#   'negative': 589,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 93,
#   'average_2weeks': 0,
#   'median_forever': 30,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '9880': {'appid': 9880,
#   'name': 'Champions Online',
#   'developer': 'Cryptic Studios',
#   'publisher': 'Perfect World Entertainment',
#   'score_rank': '',
#   'positive': 2618,
#   'negative': 1056,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 3652,
#   'average_2weeks': 338,
#   'median_forever': 123,
#   'median_2weeks': 338,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 130},
#  '1226470': {'appid': 1226470,
#   'name': 'Shadow Arena',
#   'developer': 'Pearl Abyss',
#   'publisher': 'Pearl Abyss',
#   'score_rank': '',
#   'positive': 3045,
#   'negative': 2414,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 176,
#   'average_2weeks': 0,
#   'median_forever': 143,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 34},
#  '326460': {'appid': 326460,
#   'name': 'ShellShock Live',
#   'developer': 'kChamp Games',
#   'publisher': 'kChamp Games',
#   'score_rank': '',
#   'positive': 25940,
#   'negative': 1843,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 1104,
#   'average_2weeks': 46,
#   'median_forever': 547,
#   'median_2weeks': 46,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 705},
#  '376570': {'appid': 376570,
#   'name': 'WildStar',
#   'developer': 'Carbine Studios',
#   'publisher': 'NCSOFT',
#   'score_rank': '',
#   'positive': 3665,
#   'negative': 1305,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 481,
#   'average_2weeks': 1,
#   'median_forever': 182,
#   'median_2weeks': 1,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '47410': {'appid': 47410,
#   'name': 'Stronghold Kingdoms',
#   'developer': 'FireFly Studios',
#   'publisher': 'FireFly Studios',
#   'score_rank': '',
#   'positive': 5522,
#   'negative': 2999,
#   'userscore': 0,
#   'owners': '1,000,000 .. 2,000,000',
#   'average_forever': 1185,
#   'average_2weeks': 0,
#   'median_forever': 204,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 569},
#  '835860': {'appid': 835860,
#   'name': 'Dreadnought',
#   'developer': 'Six Foot, YAGER',
#   'publisher': 'Grey Box, Six Foot',
#   'score_rank': '',
#   'positive': 3580,
#   'negative': 1885,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 163,
#   'average_2weeks': 107,
#   'median_forever': 112,
#   'median_2weeks': 107,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 58},
#  '505460': {'appid': 505460,
#   'name': 'Foxhole',
#   'developer': 'Siege Camp',
#   'publisher': 'Siege Camp',
#   'score_rank': '',
#   'positive': 16352,
#   'negative': 3247,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1605,
#   'average_2weeks': 526,
#   'median_forever': 622,
#   'median_2weeks': 526,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 2093},
#  '235340': {'appid': 235340,
#   'name': 'Prime World',
#   'developer': 'Nival',
#   'publisher': 'Nival',
#   'score_rank': '',
#   'positive': 2161,
#   'negative': 1610,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 596,
#   'average_2weeks': 0,
#   'median_forever': 90,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 7},
#  '667890': {'appid': 667890,
#   'name': 'Dead Maze',
#   'developer': 'Atelier 801',
#   'publisher': 'Atelier 801',
#   'score_rank': '',
#   'positive': 2996,
#   'negative': 1050,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 110,
#   'average_2weeks': 0,
#   'median_forever': 60,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 137},
#  '471710': {'appid': 471710,
#   'name': 'Rec Room',
#   'developer': 'Rec Room',
#   'publisher': 'Rec Room',
#   'score_rank': '',
#   'positive': 20944,
#   'negative': 1907,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 203,
#   'average_2weeks': 24,
#   'median_forever': 91,
#   'median_2weeks': 36,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1489},
#  '212160': {'appid': 212160,
#   'name': 'Vindictus',
#   'developer': 'devCAT',
#   'publisher': 'NEXON Korea Corp. &amp; NEXON America Inc.',
#   'score_rank': '',
#   'positive': 4908,
#   'negative': 2082,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 1790,
#   'average_2weeks': 0,
#   'median_forever': 120,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 362},
#  '681660': {'appid': 681660,
#   'name': 'Bless Online',
#   'developer': 'NEOWIZ BLESS STUDIO',
#   'publisher': 'NEOWIZ',
#   'score_rank': '',
#   'positive': 3811,
#   'negative': 6331,
#   'userscore': 0,
#   'owners': '500,000 .. 1,000,000',
#   'average_forever': 646,
#   'average_2weeks': 0,
#   'median_forever': 190,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '237310': {'appid': 237310,
#   'name': 'Elsword',
#   'developer': 'KOG',
#   'publisher': 'KOG Games',
#   'score_rank': '',
# ...
#  '1042590': {'appid': 1042590,
#   'name': '新巨商',
#   'developer': '渺云星',
#   'publisher': '渺云星',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 8,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 0},
#  '1097960': {'appid': 1097960,
#   'name': 'ClickRaid2',
#   'developer': 'Slikey Games',
#   'publisher': 'Slikey Games',
#   'score_rank': '',
#   'positive': 88,
#   'negative': 36,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 2},
#  '1145580': {'appid': 1145580,
#   'name': 'Wolves Team',
#   'developer': 'SFVR',
#   'publisher': 'SFVR',
#   'score_rank': '',
#   'positive': 2,
#   'negative': 2,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 0},
#  '1197440': {'appid': 1197440,
#   'name': 'Broken Spell 2',
#   'developer': 'Jaming Soo',
#   'publisher': 'YIBAILI SOFTWARE',
#   'score_rank': '',
#   'positive': 38,
#   'negative': 63,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 0},
#  '1289010': {'appid': 1289010,
#   'name': 'Haypi Monster 3',
#   'developer': 'Haypi Co., Ltd.',
#   'publisher': 'Haypi Co., Ltd.',
#   'score_rank': '',
#   'positive': 14,
#   'negative': 8,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1285210': {'appid': 1285210,
#   'name': 'CasinoLife Poker - #1 Free Texas Holdem 3D',
#   'developer': 'Kaneva LLC',
#   'publisher': 'Kaneva LLC',
#   'score_rank': '',
#   'positive': 60,
#   'negative': 24,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 16},
#  '1044180': {'appid': 1044180,
#   'name': 'Planet',
#   'developer': 'ECG Studios',
#   'publisher': 'ECG Studios',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 1,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1412240': {'appid': 1412240,
#   'name': "Lombardi's World",
#   'developer': 'Andrew Katz, Emi Schaufeld',
#   'publisher': '1 Trait Danger, Matador Records',
#   'score_rank': '',
#   'positive': 48,
#   'negative': 7,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 0},
#  '1413310': {'appid': 1413310,
#   'name': '幻刃录',
#   'developer': '天局',
#   'publisher': '天局',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1423680': {'appid': 1423680,
#   'name': 'DOGFIGHTER -WW2-',
#   'developer': 'GRUMPY, IBONG, IGGYMOB',
#   'publisher': 'IGGYMOB',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 0,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '799',
#   'initialprice': '799',
#   'discount': '0',
#   'ccu': 0},
#  '1470750': {'appid': 1470750,
#   'name': 'MAGIC POT&TER BATTLEGROUNDS',
#   'developer': 'MAGIC POT&TER BATTLEGROUNDS',
#   'publisher': 'MAGIC POT&TER BATTLEGROUNDS',
#   'score_rank': '',
#   'positive': 2,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '99',
#   'initialprice': '999',
#   'discount': '90',
#   'ccu': 0},
#  '1481060': {'appid': 1481060,
#   'name': 'The Dark World: Edge of Eternity',
#   'developer': 'Digital Nomad Lab',
#   'publisher': 'Digital Nomad Lab',
#   'score_rank': '',
#   'positive': 18,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 0},
#  '1477730': {'appid': 1477730,
#   'name': 'Extreme Soccer',
#   'developer': '9M Interactive',
#   'publisher': '9M Interactive',
#   'score_rank': '',
#   'positive': 57,
#   'negative': 32,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '1599',
#   'initialprice': '1599',
#   'discount': '0',
#   'ccu': 0},
#  '1649920': {'appid': 1649920,
#   'name': 'Coronation',
#   'developer': 'Twin Sword Studio',
#   'publisher': 'Twin Sword Studio',
#   'score_rank': '',
#   'positive': 21,
#   'negative': 4,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 3},
#  '346220': {'appid': 346220,
#   'name': 'Lif',
#   'developer': 'Imigea Ltd',
#   'publisher': 'Gamevial',
#   'score_rank': '',
#   'positive': 76,
#   'negative': 58,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '428940': {'appid': 428940,
#   'name': 'CONTASION 2',
#   'developer': 'Alex Woodcock',
#   'publisher': 'Alex Woodcock',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 7,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 0},
#  '497270': {'appid': 497270,
#   'name': 'MIGHT',
#   'developer': 'Fast Forward Games',
#   'publisher': 'Fast Forward Games',
#   'score_rank': '',
#   'positive': 22,
#   'negative': 16,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '503340': {'appid': 503340,
#   'name': 'Dig 4 Destruction',
#   'developer': 'COLOPL, Inc.',
#   'publisher': 'COLOPL, Inc.',
#   'score_rank': '',
#   'positive': 103,
#   'negative': 11,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '1199',
#   'initialprice': '1199',
#   'discount': '0',
#   'ccu': 4},
#  '671860': {'appid': 671860,
#   'name': 'BattleBit Remastered',
#   'developer': 'MrOkiDoki, BATTLEKOT, TheLiquidHorse',
#   'publisher': 'MrOkiDoki',
#   'score_rank': '',
#   'positive': 0,
#   'negative': 0,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '684930': {'appid': 684930,
#   'name': 'Fantasy ERA',
#   'developer': 'Fatih KAYA',
#   'publisher': 'FKgames',
#   'score_rank': '',
#   'positive': 7,
#   'negative': 10,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 0},
#  '708930': {'appid': 708930,
#   'name': 'Diceonline.net',
#   'developer': 'Alexander Shvab',
#   'publisher': 'Alexander Shvab',
#   'score_rank': '',
#   'positive': 14,
#   'negative': 19,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '797660': {'appid': 797660,
#   'name': 'God Test',
#   'developer': 'God Test',
#   'publisher': 'God Test',
#   'score_rank': '',
#   'positive': 6,
#   'negative': 8,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '843270': {'appid': 843270,
#   'name': 'Flapping Over It',
#   'developer': 'Stequer',
#   'publisher': 'Stequer',
#   'score_rank': '',
#   'positive': 8,
#   'negative': 11,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '99',
#   'initialprice': '99',
#   'discount': '0',
#   'ccu': 0},
#  '919200': {'appid': 919200,
#   'name': 'Special Warfare - 特战之王',
#   'developer': 'battle fire studio',
#   'publisher': 'battle fire studio',
#   'score_rank': '',
#   'positive': 45,
#   'negative': 22,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 2},
#  '767300': {'appid': 767300,
#   'name': 'War of Conquest',
#   'developer': 'IronZog',
#   'publisher': 'IronZog',
#   'score_rank': '',
#   'positive': 12,
#   'negative': 11,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '758880': {'appid': 758880,
#   'name': 'RedSun RTS',
#   'developer': 'Yuri Eletskikh',
#   'publisher': 'redsungames',
#   'score_rank': '',
#   'positive': 10,
#   'negative': 13,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '699',
#   'initialprice': '699',
#   'discount': '0',
#   'ccu': 0},
#  '887740': {'appid': 887740,
#   'name': '老虎游戏-tiger casino&slot game',
#   'developer': '上海信虎文化传播有限公司',
#   'publisher': '上海信虎文化传播有限公司',
#   'score_rank': '',
#   'positive': 12,
#   'negative': 18,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '969970': {'appid': 969970,
#   'name': 'BattleRush: Ardennes Assault',
#   'developer': 'Thunder Devs.',
#   'publisher': 'Thunder Devs.',
#   'score_rank': '',
#   'positive': 34,
#   'negative': 28,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 0},
#  '867400': {'appid': 867400,
#   'name': 'Out of Reach: Treasure Royale',
#   'developer': 'Space Boat Studios',
#   'publisher': 'PlayWay S.A.',
#   'score_rank': '',
#   'positive': 228,
#   'negative': 120,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 1},
#  '892510': {'appid': 892510,
#   'name': 'Slay Together',
#   'developer': 'Owl Tribe Entertainment',
#   'publisher': 'Owl Tribe Entertainment',
#   'score_rank': '',
#   'positive': 260,
#   'negative': 108,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1021880': {'appid': 1021880,
#   'name': 'StarWheels',
#   'developer': 'Black Smokers Entertainment',
#   'publisher': 'Black Smokers Entertainment',
#   'score_rank': '',
#   'positive': 34,
#   'negative': 0,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 0},
#  '1112870': {'appid': 1112870,
#   'name': 'Cardaria',
#   'developer': 'TripleSky',
#   'publisher': 'TripleSky',
#   'score_rank': '',
#   'positive': 17,
#   'negative': 11,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1180630': {'appid': 1180630,
#   'name': 'Swordia',
#   'developer': 'Affliction Networks',
#   'publisher': 'Affliction Networks',
#   'score_rank': '',
#   'positive': 11,
#   'negative': 10,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1218950': {'appid': 1218950,
#   'name': '战神七魄',
#   'developer': '战神七魄',
#   'publisher': '战神七魄',
#   'score_rank': '',
#   'positive': 7,
#   'negative': 8,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1222720': {'appid': 1222720,
#   'name': 'Journey To Planet Earth',
#   'developer': 'BBLOCk Digital, Enrico Galeazzi Architecture Studio',
#   'publisher': 'BBLOCK Digital',
#   'score_rank': '',
#   'positive': 7,
#   'negative': 9,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1280100': {'appid': 1280100,
#   'name': 'Element Battle Royale',
#   'developer': 'YoAvrageStudios',
#   'publisher': 'YoAvrageStudios',
#   'score_rank': '',
#   'positive': 49,
#   'negative': 33,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '1265850': {'appid': 1265850,
#   'name': 'Chatventures',
#   'developer': 'Sokpop Collective',
#   'publisher': 'Sokpop Collective',
#   'score_rank': '',
#   'positive': 80,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '299',
#   'initialprice': '299',
#   'discount': '0',
#   'ccu': 0},
#  '1390080': {'appid': 1390080,
#   'name': 'Tank Rampage',
#   'developer': 'targim.',
#   'publisher': 'targim.',
#   'score_rank': '',
#   'positive': 0,
#   'negative': 1,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '399',
#   'initialprice': '399',
#   'discount': '0',
#   'ccu': 0},
#  '994910': {'appid': 994910,
#   'name': 'Poker Master',
#   'developer': 'LoongCrown',
#   'publisher': 'LoongCrown',
#   'score_rank': '',
#   'positive': 341,
#   'negative': 30,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9},
#  '1432710': {'appid': 1432710,
#   'name': '新魔剑（New Magic Sword）',
#   'developer': 'Magic',
#   'publisher': 'Magic',
#   'score_rank': '',
#   'positive': 23,
#   'negative': 28,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 53},
#  '1469310': {'appid': 1469310,
#   'name': '梦幻江湖',
#   'developer': '上海摩力游数字娱乐有限公司',
#   'publisher': '上海摩力游数字娱乐有限公司',
#   'score_rank': '',
#   'positive': 3,
#   'negative': 3,
#   'userscore': 0,
#   'owners': '0 .. 20,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  ...}

# %%
import steamspypi
import pandas as pd

data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '7'

data = steamspypi.download(data_request)
df = pd.read_json("20211115_steamspy_page_3.json")

test = df.transpose()
test
# Out:
#            appid                              name  \
# 720560    720560          Vigil: The Longest Night
# 602320    602320                    Train Valley 2
# 373180    373180            Kung Fury: Street Rage
# 336520    336520       Might & Magic Heroes Online
# 348510    348510         Autobahn Police Simulator
# ...          ...                               ...
# 596650    596650        Tap Adventure: Time Travel
# 294810    294810  BlazBlue: Continuum Shift Extend
# 531960    531960                      Bloody Walls
# 323720    323720                   Decay: The Mare
# 1145960  1145960                    The White Door
#
#                                                  developer  \
# 720560                                   Glass Heart Games
# 602320   Alexey Davydov, Sergey Dvoynikov, Timofey Shar...
# 373180                                   Hello There Games
# 336520                                           Blue Byte
# 348510                                          Z-Software
# ...                                                    ...
# 596650                                    Avallon Alliance
# 294810                                    Arc System Works
# 531960                                           L. Stotch
# 323720                               Shining Gate Software
# 1145960                                         Rusty Lake
#
#                         publisher score_rank positive negative userscore  \
# 720560              Neon Doctrine                2062      250         0
# 602320     Flazm, META Publishing                1594      154         0
# 373180          Hello There Games                2076      226         0
# 336520                    Ubisoft                 311      459         0
# 348510              Aerosoft GmbH                 593     1382         0
# ...                           ...        ...      ...      ...       ...
# 596650              Panoramik inc                 550      333         0
# 294810   H2 Interactive Co., Ltd.                1250      120         0
# 531960                  L. Stotch                 871      259         0
# 323720     Daedalic Entertainment                1217      380         0
# 1145960               Second Maze                3628      227         0
#
#                      owners average_forever average_2weeks median_forever  \
# 720560   200,000 .. 500,000             335              0            469
# 602320   200,000 .. 500,000             326              0            238
# 373180   200,000 .. 500,000             142              0            142
# 336520   200,000 .. 500,000             791              0            794
# 348510   200,000 .. 500,000             594              0             26
# ...                     ...             ...            ...            ...
# 596650   100,000 .. 200,000             140              0             74
# 294810   100,000 .. 200,000             294            182            213
# 531960   100,000 .. 200,000              27              0             47
# 323720   100,000 .. 200,000             139              0            200
# 1145960  100,000 .. 200,000             125              0            164
#
#         median_2weeks price initialprice discount  ccu
# 720560              0  2199         2199        0   54
# 602320              0  1499         1499        0  141
# 373180              0   699          699        0    9
# 336520              0     0            0        0    0
# 348510              0   999          999        0    6
# ...               ...   ...          ...      ...  ...
# 596650              0     0            0        0    5
# 294810            182   999          999        0    8
# 531960              0     0            0        0    1
# 323720              0   499          499        0    2
# 1145960             0   399          399        0   27
#
# [1000 rows x 17 columns]

# %%
import steamspypi

data = steamspypi.download_all_pages(num_pages=44)
# Out:
# Downloading page=0 on Wed Nov 17 12:49:20 2021
# Sleeping for 70 seconds on Wed Nov 17 12:49:20 2021
# Downloading page=1 on Wed Nov 17 12:50:30 2021
# Sleeping for 70 seconds on Wed Nov 17 12:50:31 2021
# Downloading page=2 on Wed Nov 17 12:51:41 2021
# Sleeping for 70 seconds on Wed Nov 17 12:51:41 2021
# Downloading page=3 on Wed Nov 17 12:52:51 2021
# Sleeping for 70 seconds on Wed Nov 17 12:52:51 2021
# Downloading page=4 on Wed Nov 17 12:54:01 2021
# Sleeping for 70 seconds on Wed Nov 17 12:54:02 2021
# Downloading page=5 on Wed Nov 17 12:55:12 2021
# Sleeping for 70 seconds on Wed Nov 17 12:55:12 2021
# Downloading page=6 on Wed Nov 17 12:56:22 2021
# Sleeping for 70 seconds on Wed Nov 17 12:56:23 2021
# Downloading page=7 on Wed Nov 17 12:57:33 2021
# Sleeping for 70 seconds on Wed Nov 17 12:57:33 2021

# %%
pip install -r requirements.txt
