# %%
#import relevant libraries
import pandas as pd
import json
from glob import glob
import time

# %%
#functions to read/manipulate the data
def print_with_sleep(message, sleep_time):
    print(message)
    time.sleep(sleep_time)

def get_details_df(folder_path):
    df = pd.DataFrame()
    #df = pd.concat((pd.read_json(file) for file in glob(folder_path + "*.json")), ignore_index = True)
    for file in glob(folder_path + "*.json"):
        with open(file, "r") as json_file:
            json_data = json.load(json_file)
            for attribute, value in json_data.items():
                df = df.append(value, ignore_index=True)            
    return df

def get_details_df_improved(folder_path):
    dict_list = []
    for file in glob(folder_path + "*.json"):
        with open(file, "r") as json_file:
            df = pd.read_json(json_file)
            dict_list.append(df.transpose())
    result = pd.concat(dict_list)
    return result

def get_details_dict(folder_path):
    details = dict()
    for file in glob(folder_path + "*.json"):
        with open(file, "r") as json_file:
            json_data = json.load(json_file)
    return details        

#Function used to get userscore
def divide(positive, negative):
    return positive / (positive+negative)
    if positive == 0:
        return 0
    return positive / (positive + negative)

def convert_cents_to_dollars(price_column_series):
    column = price_column_series.astype('string')
    column = column.astype(int) / 100
    return column

# %%
#Weirdly slow - don't use
#chunks_folder_path = "./app_details_chunks/"
#df = get_details_df(chunks_folder_path)
#df
#df.info()
#df.describe()

# %%
#A more effective way to get the data
chunks_folder_path = "./app_details_chunks/"
all_details_df = get_details_df_improved(chunks_folder_path)
all_details_df
# Out:
#            appid                             name                   developer  \
# 10            10                   Counter-Strike                       Valve
# 1000000  1000000                        ASCENXION      IndigoBlue Game Studio
# 1000010  1000010                      Crown Trick                NEXT Studios
# 1000030  1000030      Cook, Serve, Delicious! 3?!         Vertigo Gaming Inc.
# 1000040  1000040                             细胞战争               DoubleC Games
# ...          ...                              ...                         ...
# 1369950  1369950  亡命尸潮惊魂夜 Escape Zombies At Night            morescore studio
# 1369980  1369980         Abyss The Forgotten Past                 OWG Studios
# 1370000  1370000        Max and the Book of Chaos  Orenji Games Entertainment
# 1370040  1370040                       Underlings               One Man Games
# 1370130  1370130                 Rezzil Player 21                      Rezzil
#
#                           publisher score_rank positive negative userscore  \
# 10                            Valve              184180     4787         0
# 1000000    PsychoFlux Entertainment                  26        4         0
# 1000010        Team17, NEXT Studios                3568      526         0
# 1000030         Vertigo Gaming Inc.                1347       79         0
# 1000040               DoubleC Games                   0        1         0
# ...                             ...        ...      ...      ...       ...
# 1369950            morescore studio                   5        3         0
# 1369980                 OWG Studios                   9        4         0
# 1370000  Orenji Games Entertainment                   5        1         0
# 1370040               One Man Games                  13        6         0
# 1370130                      Rezzil                  15        1         0
#
#                            owners average_forever average_2weeks  \
# 10       10,000,000 .. 20,000,000           11054            339
# 1000000               0 .. 20,000               0              0
# 1000010        200,000 .. 500,000             489              0
# 1000030         50,000 .. 100,000             310              0
# 1000040               0 .. 20,000               0              0
# ...                           ...             ...            ...
# 1369950               0 .. 20,000               0              0
# 1369980               0 .. 20,000               0              0
# 1370000               0 .. 20,000               0              0
# 1370040               0 .. 20,000               0              0
# 1370130          20,000 .. 50,000               0              0
#
#         median_forever median_2weeks price initialprice discount    ccu  \
# 10                 220            81   999          999        0  13899
# 1000000              0             0   999          999        0      0
# 1000010            615             0   799         1999       60    217
# 1000030            367             0  1999         1999        0     41
# 1000040              0             0   199          199        0      0
# ...                ...           ...   ...          ...      ...    ...
# 1369950              0             0    99           99        0      0
# 1369980              0             0   399          399        0      0
# 1370000              0             0   899          899        0      0
# 1370040              0             0   999          999        0      0
# 1370130              0             0     0            0        0      0
#
#                                                  languages  \
# 10       English, French, German, Italian, Spanish - Sp...
# 1000000                Korean, English, Simplified Chinese
# 1000010  Simplified Chinese, English, Japanese, Traditi...
# 1000030                                            English
# 1000040         English, Not supported, Simplified Chinese
# ...                                                    ...
# 1369950                        English, Simplified Chinese
# 1369980                       English, Portuguese - Brazil
# 1370000                           English, Spanish - Spain
# 1370040                                            English
# 1370130  English, German, Japanese, Korean, Simplified ...
#
#                                                genre  \
# 10                                            Action
# 1000000                     Action, Adventure, Indie
# 1000010              Adventure, Indie, RPG, Strategy
# 1000030          Action, Indie, Simulation, Strategy
# 1000040            Action, Casual, Indie, Simulation
# ...                                              ...
# 1369950                Action, Adventure, Indie, RPG
# 1369980  Action, Adventure, Indie, RPG, Early Access
# 1370000                     Action, Adventure, Indie
# 1370040    Action, Adventure, Indie, RPG, Simulation
# 1370130     Casual, Free to Play, Simulation, Sports
#
#                                                       tags
# 10       {'Action': 5370, 'FPS': 4794, 'Multiplayer': 3...
# 1000000  {'Shoot 'Em Up': 186, 'Metroidvania': 181, 'Bu...
# 1000010  {'Rogue-like': 260, 'Turn-Based Combat': 244, ...
# 1000030  {'Typing': 217, 'Casual': 208, 'Management': 2...
# 1000040  {'Action': 22, 'Casual': 22, 'Indie': 21, 'Sim...
# ...                                                    ...
# 1369950  {'Post-apocalyptic': 103, 'Survival': 96, 'Adv...
# 1369980  {'Adventure': 60, 'Action': 52, 'Action-Advent...
# 1370000  {'Action': 68, 'Adventure': 61, 'Action-Advent...
# 1370040  {'Open World Survival Craft': 327, 'Survival':...
# 1370130  {'Sports': 65, 'VR': 53, 'Arcade': 42, 'e-spor...
#
# [42635 rows x 20 columns]

# %%
#Clean the data
data_df = all_details_df

#Remove games with too much issing data
#data_df[data_df['price'].isnull() == True]
#remove_these_games = ['530940', '657860', '684740', '846260']
data_df = data_df.drop(data_df.loc[data_df['price'].isnull() == True].index)
#Remove games without any language defined
data_df = data_df.drop(data_df.loc[data_df['languages'].isnull() == True].index)



data_df.appid = data_df.appid.astype(int)
data_df.name = data_df.name.astype('string')
data_df.developer = data_df.developer.astype('string')
data_df.publisher = data_df.publisher.astype('string')
#data_df.score_rank = data_df.score_rank.astype('category')
data_df = data_df.drop('score_rank', 1)
data_df.positive = data_df.positive.astype(int)
data_df.negative = data_df.negative.astype(int)
data_df.userscore = divide(data_df.positive, data_df.negative)
data_df.owners = data_df.owners.astype('category')
data_df.average_forever = data_df.average_forever.astype(int)
data_df.average_2weeks = data_df.average_2weeks.astype(int)
data_df.median_forever = data_df.median_forever.astype(int)
data_df.median_2weeks = data_df.median_2weeks.astype(int)
data_df.price = convert_cents_to_dollars(data_df.price)
data_df.initialprice = convert_cents_to_dollars(data_df.initialprice)
data_df = data_df.drop('discount', 1)
data_df.ccu = data_df.ccu.astype(int)
#Leave languages as is for now
data_df = data_df.drop('genre', 1)
#Leave tags as is for now

data_df.info()
data_df.dtypes
data_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42631 entries, 10 to 1370130
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            42631 non-null  int32
#  1   name             42631 non-null  string
#  2   developer        42631 non-null  string
#  3   publisher        42631 non-null  string
#  4   positive         42631 non-null  int32
#  5   negative         42631 non-null  int32
#  6   userscore        42575 non-null  float64
#  7   owners           42631 non-null  category
#  8   average_forever  42631 non-null  int32
#  9   average_2weeks   42631 non-null  int32
#  10  median_forever   42631 non-null  int32
#  11  median_2weeks    42631 non-null  int32
#  12  price            42631 non-null  float64
#  13  initialprice     42631 non-null  float64
#  14  ccu              42631 non-null  int32
#  15  languages        42631 non-null  object
#  16  tags             42631 non-null  object
# dtypes: category(1), float64(3), int32(8), object(2), string(3)
# memory usage: 5.3+ MB
#            appid                          name               developer  \
# 10            10                Counter-Strike                   Valve
# 1000000  1000000                     ASCENXION  IndigoBlue Game Studio
# 1000010  1000010                   Crown Trick            NEXT Studios
# 1000030  1000030   Cook, Serve, Delicious! 3?!     Vertigo Gaming Inc.
# 1000040  1000040                          细胞战争           DoubleC Games
# 1000080  1000080                       Zengeon      IndieLeague Studio
# 1000110  1000110          Jumping Master(跳跳大咖)               重庆环游者网络科技
# 1000130  1000130                 Cube Defender        Simon Codrington
# 1000280  1000280  Tower of Origin2-Worm's Nest            Villain Role
# 1000310  1000310                       人气动漫大乱斗          海南众铖互娱网络科技有限公司
#
#                         publisher  positive  negative  userscore  \
# 10                          Valve    184180      4787   0.974668
# 1000000  PsychoFlux Entertainment        26         4   0.866667
# 1000010      Team17, NEXT Studios      3568       526   0.871519
# 1000030       Vertigo Gaming Inc.      1347        79   0.944600
# 1000040             DoubleC Games         0         1   0.000000
# 1000080                  2P Games      1004       402   0.714083
# 1000110                 重庆环游者网络科技        52        33   0.611765
# 1000130          Simon Codrington         6         0   1.000000
# 1000280              Villain Role        18         5   0.782609
# 1000310            海南众铖互娱网络科技有限公司         1         5   0.166667
#
#                            owners  average_forever  average_2weeks  \
# 10       10,000,000 .. 20,000,000            11054             339
# 1000000               0 .. 20,000                0               0
# 1000010        200,000 .. 500,000              489               0
# 1000030         50,000 .. 100,000              310               0
# 1000040               0 .. 20,000                0               0
# 1000080         50,000 .. 100,000                8               0
# 1000110          20,000 .. 50,000                0               0
# 1000130               0 .. 20,000                0               0
# 1000280               0 .. 20,000                0               0
# 1000310               0 .. 20,000                0               0
#
#          median_forever  median_2weeks  price  initialprice    ccu  \
# 10                  220             81   9.99          9.99  13899
# 1000000               0              0   9.99          9.99      0
# 1000010             615              0   7.99         19.99    217
# 1000030             367              0  19.99         19.99     41
# 1000040               0              0   1.99          1.99      0
# 1000080              13              0   9.99         19.99      4
# 1000110               0              0   0.00          0.00      0
# 1000130               0              0   2.99          2.99      0
# 1000280               0              0  13.99         13.99      1
# 1000310               0              0   0.99          0.99      0
#
#                                                  languages  \
# 10       English, French, German, Italian, Spanish - Sp...
# 1000000                Korean, English, Simplified Chinese
# 1000010  Simplified Chinese, English, Japanese, Traditi...
# 1000030                                            English
# 1000040         English, Not supported, Simplified Chinese
# 1000080  English, Simplified Chinese, Traditional Chine...
# 1000110   English, Simplified Chinese, Traditional Chinese
# 1000130                                            English
# 1000280   Simplified Chinese, English, Traditional Chinese
# 1000310         English, Not supported, Simplified Chinese
#
#                                                       tags
# 10       {'Action': 5370, 'FPS': 4794, 'Multiplayer': 3...
# 1000000  {'Shoot 'Em Up': 186, 'Metroidvania': 181, 'Bu...
# 1000010  {'Rogue-like': 260, 'Turn-Based Combat': 244, ...
# 1000030  {'Typing': 217, 'Casual': 208, 'Management': 2...
# 1000040  {'Action': 22, 'Casual': 22, 'Indie': 21, 'Sim...
# 1000080  {'Action': 91, 'Indie': 86, 'RPG': 82, 'Advent...
# 1000110  {'Free to Play': 26, 'Massively Multiplayer': ...
# 1000130  {'Indie': 31, 'Casual': 31, 'Tower Defense': 1...
# 1000280  {'Turn-Based Strategy': 40, 'Word Game': 38, '...
# 1000310  {'RPG': 32, 'Action': 31, 'Strategy': 29, 'Com...

# %%
#Save cleaned data for analyzing
#use csv because easy
data_df.to_csv("cleaned_data.csv")
